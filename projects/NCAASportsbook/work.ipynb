# %%
#ORIGINAL TEAM ABBREVIATIONS DB

# abr = pd.DataFrame(columns=['team', 'abr'])

# pg = pd.DataFrame()
# i, start = 1, 0
# while start != -1:
#     s = 'https://basketball.realgm.com/ncaa/stats/%s/Averages/Qualified/All/Season/PG/points/desc/%s' % (YEAR, i)
#     url = requests.get(s)
#     parse = BeautifulSoup(url.text, "lxml").prettify()
#     start = parse.find("<table")
#     end = parse.find("</table")
#     if start != -1:
#       temp = re.findall('title=".*?"', parse[start:end+8])
#       temp = [x[7:-1] for x in temp]
#       df = pd.read_html(parse[start:end+8])[0][['Team']]
#       df.rename(columns={"Team": "abr"}, inplace=True)
#       df['team'] = temp
#       abr = pd.concat([abr, df])
#       i+=1

# i, start = 1, 0
# while start != -1:
#     s = 'https://basketball.realgm.com/ncaa/stats/%s/Averages/Qualified/All/Season/SG/points/desc/%s' % (YEAR, i)
#     url = requests.get(s)
#     parse = BeautifulSoup(url.text, "lxml").prettify()
#     start = parse.find("<table")
#     end = parse.find("</table")
#     if start != -1:
#       temp = re.findall('title=".*?"', parse[start:end+8])
#       temp = [x[7:-1] for x in temp]
#       df = pd.read_html(parse[start:end+8])[0][['Team']]
#       df.rename(columns={"Team": "abr"}, inplace=True)
#       df['team'] = temp
#       abr = pd.concat([abr, df])
#       i+=1

# abr.drop_duplicates(inplace=True)

# abr.reset_index().drop('index', axis=1, inplace=True)

# x = pd.read_csv('abbreviations.csv')
# x.drop('Unnamed: 0', axis = 1, inplace=True)
# x = x.merge(tor['Team'], how='left', left_on='team', right_on='Team')
# x.rename({'Team':'tor'}, axis = 1, inplace=True)
# x = x.merge(tor['Team'], how='left', left_on='abr', right_on='Team')
# x['tor'] = x['tor'].fillna(x['Team'])
# x.drop('Team', axis=1, inplace=True)
# x = x.merge(tor['Team'], how='left', left_on='line', right_on='Team')
# x['tor'] = x['tor'].fillna(x['Team'])
# x.drop('Team', axis=1, inplace=True)
# x[pd.isna(x['tor']) == True].sort_values('team', ascending=True)
# df = pd.DataFrame()
# df['test'] = x['team'].apply(lambda x: (x[:-3] + '.') if (x[-5:] == 'State') else np.NaN)
# x['tor'] = x['tor'].fillna(df['test'])
# x.loc[ x["team"] == 'Alabama A&amp;M', 'tor'] = 'Alabama A&M'
# x.loc[ x["team"] == 'American University', 'tor'] = 'American'
# x.loc[ x["team"] == 'Arkansas-Pine Bluff', 'tor'] = 'Arkansas Pine Bluff'
# x.loc[ x["team"] == 'Army West Point', 'tor'] = 'Army'
# x.loc[ x["team"] == 'Bethune-Cookman', 'tor'] = 'Bethune Cookman'
# x.loc[ x["team"] == 'Cal State Bakersfield', 'tor'] = 'Cal St. Bakersfield'
# x.loc[ x["team"] == 'Cal State Fullerton', 'tor'] = 'Cal St. Fullerton'
# x.loc[ x["team"] == 'Cal State Northridge', 'tor'] = 'Cal St. Northridge'
# x.loc[ x["team"] == 'California Baptist', 'tor'] = 'Cal Baptist'
# x.loc[ x["team"] == 'Charleston', 'tor'] = 'College of Charleston'
# x.loc[ x["team"] == 'Detroit-Mercy', 'tor'] = 'Detroit'
# x.loc[ x["team"] == 'Florida A&amp;M', 'tor'] = 'Florida A&M'
# x.loc[ x["team"] == 'Gardner-Webb', 'tor'] = 'Gardner Webb'
# x.loc[ x["team"] == 'Illinois-Chicago', 'tor'] = 'Illinois Chicago'
# x.loc[ x["team"] == 'Long Island', 'tor'] = 'LIU Brooklyn'
# x.loc[ x["team"] == 'Louisiana', 'tor'] = 'Louisiana Lafayette'
# x.loc[ x["team"] == 'Louisiana-Monroe', 'tor'] = 'Louisiana Monroe'
# x.loc[ x["team"] == 'Loyola (IL)', 'tor'] = 'Loyola MD'
# x.loc[ x["team"] == 'Loyola (MD)', 'tor'] = 'Loyola Chicago'
# x.loc[ x["team"] == 'Maryland-Eastern Shore', 'tor'] = 'Maryland Eastern Shore'
# x.loc[ x["team"] == 'Merrimack College', 'tor'] = 'Merrimack'
# x.loc[ x["team"] == 'Miami (FL)', 'tor'] = 'Miami FL'
# x.loc[ x["team"] == 'Miami (OH)', 'tor'] = 'Miami OH'
# x.loc[ x["team"] == 'Mount St. Mary', 'tor'] = "Mount St. Mary's"
# x.loc[ x["team"] == 'North Carolina A&amp;T', 'tor'] = 'North Carolina A&T'
# x.loc[ x["team"] == 'Ole Miss', 'tor'] = 'Mississippi'
# x.loc[ x["team"] == 'Omaha', 'tor'] = 'Nebraska Omaha'
# x.loc[ x["team"] == 'Pennsylvania', 'tor'] = 'Penn'
# x.loc[ x["team"] == 'Prairie View A&amp;M', 'tor'] = 'Prairie View A&M'
# x.loc[ x["team"] == 'Queens University', 'tor'] = '	Queens'
# x.loc[ x["team"] == 'SIU-Edwardsville', 'tor'] = 'SIU Edwardsville'
# x.loc[ x["team"] == 'Saint Joseph', 'tor'] = "Saint Joseph's"
# x.loc[ x["team"] == 'Saint Mary', 'tor'] = "Saint Mary's"
# x.loc[ x["team"] == 'Saint Peter', 'tor'] = "Saint Peter's"
# x.loc[ x["team"] == 'Southern Mississippi', 'tor'] = 'Southern Miss'
# x.loc[ x["team"] == 'St. Francis (PA)', 'tor'] = 'St. Francis PA'
# x.loc[ x["team"] == 'St. Thomas-Minnesota', 'tor'] = 'St. Thomas'
# x.loc[ x["team"] == 'Tennessee-Martin', 'tor'] = 'Tennessee Martin'
# x.loc[ x["team"] == 'Texas A&amp;M', 'tor'] = 'Texas A&M'
# x.loc[ x["team"] == 'Texas A&amp;M Commerce', 'tor'] = 'Texas A&M Commerce'
# x.loc[ x["team"] == 'Texas A&amp;M-CC', 'tor'] = 'Texas A&M Corpus Chris'
# x.loc[ x["team"] == 'Texas-Arlington', 'tor'] = 'UT Arlington'
# x.loc[ x["team"] == 'Texas-RGV', 'tor'] = 'UT Rio Grande Valley'
# x.loc[ x["team"] == 'UConn', 'tor'] = 'Connecticut'
# x.loc[ x["team"] == 'William &amp; Mary', 'tor'] = 'William & Mary'


# x = pd.read_csv('abbreviations.csv')
# x.drop('Unnamed: 0', axis = 1, inplace=True)
# x = x.sort_values('team').reset_index()

# hca = pd.read_csv('HCA.csv')
# hca
# x['hca'] = np.nan
# x[['team', 'abr', 'line', 'tor']] = x[['team', 'abr', 'line', 'tor']].astype(str)
# x = x.merge(hca, how='left', left_on='team', right_on='Team')
# x['hca'] = x['hca'].fillna(x['Team'])
# x = x[['team', 'abr', 'line', 'tor', 'hca']]
# x = x.merge(hca, how='left', left_on='abr', right_on='Team')
# x['hca'] = x['hca'].fillna(x['Team'])
# x = x[['team', 'abr', 'line', 'tor', 'hca']]
# x = x.merge(hca, how='left', left_on='line', right_on='Team')
# x['hca'] = x['hca'].fillna(x['Team'])
# x = x[['team', 'abr', 'line', 'tor', 'hca']]
# x = x.merge(hca, how='left', left_on='tor', right_on='Team')
# x['hca'] = x['hca'].fillna(x['Team'])
# x = x[['team', 'abr', 'line', 'tor', 'hca']]
# m = pd.DataFrame()
# m['tor'] = x['tor']
# m["tor"] = m['tor'].apply(lambda x: x if x[-3:] == 'St.' else np.nan)  
# x = x.join(m, how='left', rsuffix='x')
# x['hca'] = x['hca'].fillna(x['torx'].str[:-1])
# x = x[['team', 'abr', 'line', 'tor', 'hca']]

# x.loc[x['team'] == 'Alabama A&amp;M', ['hca']] = "Alabama AM"
# x.loc[x['team'] == 'American University', ['hca']] = "American U"
# x.loc[x['team'] == 'Boston University', ['hca']] = "Boston U"
# x.loc[x['team'] == 'Cal Poly', ['hca']] = "Cal Poly SLO"
# x.loc[x['team'] == 'Cal State Fullerton', ['hca']] = "Cal St Fullerton"
# x.loc[x['team'] == 'Elon', ['hca']] = "Elon University"
# x.loc[x['team'] == 'Fort Wayne', ['hca']] = "IUPU Ft Wayne"
# x.loc[x['team'] == 'Florida A&amp;M', ['hca']] = "Florida AM"
# x.loc[x['team'] == 'LSU', ['hca']] = "Louisiana State"
# x.loc[x['team'] == 'Little Rock', ['hca']] = "Arkansas Little Rock"
# x.loc[x['team'] == 'Loyola (IL)', ['hca']] = "Loyola Chicago"
# x.loc[x['team'] == 'Maryland-Eastern Shore', ['hca']] = "Maryland E Shore"
# x.loc[x['team'] == 'Miami (FL)', ['hca']] = "Miami Florida"
# x.loc[x['team'] == 'Milwaukee', ['hca']] = "Wis Milwaukee"
# x.loc[x['team'] == 'Monmouth', ['hca']] = "Monmouth NJ"
# x.loc[x['team'] == 'Mount St. Mary', ['hca']] = "Mount St Marys"
# x.loc[x['team'] == 'North Carolina A&amp;T', ['hca']] = "NoCarolina AT"
# x.loc[x['team'] == 'Prairie View A&amp;M', ['hca']] = "Prairie View AM"
# x.loc[x['team'] == 'Saint Joseph', ['hca']] = "St Josephs"
# x.loc[x['team'] == 'Saint Mary', ['hca']] = "St Marys"
# x.loc[x['team'] == 'Saint Peter', ['hca']] = "St Peters"
# x.loc[x['team'] == 'IUPUI', ['hca']] = "Indiana Purdue"
# x.loc[x['team'] == 'St. Bonaventure', ['hca']] = "St Bonaventure"
# x.loc[x['team'] == 'St. Francis (PA)', ['hca']] = "St Francis PA"
# x.loc[x['team'] == 'St. John', ['hca']] = "St Johns"
# x.loc[x['team'] == 'Stephen F. Austin', ['hca']] = "Stephen F Austin"
# x.loc[x['team'] == 'TCU', ['hca']] = "Texas Christian"
# x.loc[x['team'] == 'Tennessee-Martin', ['hca']] = "Tenn Martin"
# x.loc[x['team'] == 'Texas A&amp;M', ['hca']] = "Texas AM"
# x.loc[x['team'] == 'Texas A&amp;M Commerce', ['hca']] = "Texas AM CC"
# x.loc[x['team'] == 'Texas-Arlington', ['hca']] = "Texas Arlington"
# x.loc[x['team'] == 'Texas-San Antonio', ['hca']] = "Texas San Antonio"
# x.loc[x['team'] == 'The Citadel', ['hca']] = "Citadel"
# x.loc[x['team'] == 'UCF', ['hca']] = "Central Florida"
# x.loc[x['team'] == 'UMBC', ['hca']] = "MD Baltimore Cty"
# x.loc[x['team'] == 'UNC Asheville', ['hca']] = "NC Asheville"
# x.loc[x['team'] == 'UNC Greensboro', ['hca']] = "NC Greensboro"
# x.loc[x['team'] == 'UNC Wilmington', ['hca']] = "NC Wilmington"
# x.loc[x['team'] == 'USC', ['hca']] = "Southern California"
# x.loc[x['team'] == 'UTEP', ['hca']] = "Texas El Paso"
# x.loc[x['team'] == 'William &amp; Mary', ['hca']] = "William Mary"

# x[pd.isna(x['hca']) == True].sort_values('team', ascending=True)

# %%
#ADD SOS ABBREVIATIONS

# url = requests.get('https://www.teamrankings.com/ncaa-basketball/ranking/schedule-strength-by-other')
# parse = BeautifulSoup(url.text, "lxml").prettify()
# start = parse.find("<table")
# end = parse.find("</table")
# sos = pd.read_html(parse[start:end+8])[0].sort_values('Team').reset_index().rename({'Team':'SOSTeam'}, axis = 1)
# sos.drop(['Rank', 'Hi', 'Low', 'Last', 'index'], axis = 1, inplace = True)
# sos['SOSTeam'] = sos['SOSTeam'].apply(lambda x: re.split(' \((?:.(?!\())+$', x)[0][:-1])
# import pandas as pd
# x = pd.read_csv('abbreviations.csv')
# x['sos'] = pd.NA
# x = x.merge(sos['SOSTeam'], how='left', left_on='team', right_on='SOSTeam')
# x['sos'] = x['sos'].fillna(x['SOSTeam'])
# x.drop('SOSTeam', axis = 1, inplace = True)
# x = x.merge(sos['SOSTeam'], how='left', left_on='abr', right_on='SOSTeam')
# x['sos'] = x['sos'].fillna(x['SOSTeam'])
# x.drop('SOSTeam', axis = 1, inplace = True)
# x = x.merge(sos['SOSTeam'], how='left', left_on='line', right_on='SOSTeam')
# x['sos'] = x['sos'].fillna(x['SOSTeam'])
# x.drop('SOSTeam', axis = 1, inplace = True)
# x = x.merge(sos['SOSTeam'], how='left', left_on='sos', right_on='SOSTeam')
# x['sos'] = x['sos'].fillna(x['SOSTeam'])
# x.drop('SOSTeam', axis = 1, inplace = True)
# x = x.merge(sos['SOSTeam'], how='left', left_on='hca', right_on='SOSTeam')
# x['sos'] = x['sos'].fillna(x['SOSTeam'])
# x.drop(['SOSTeam', 'Unnamed: 0'], axis = 1, inplace = True)

# x[x['sos'] != x['sos']]

# x.loc[ x["team"] == 'Abilene Christian', 'sos'] = 'Abl Christian'
# x.loc[ x["team"] == 'Alabama A&amp;M', 'sos'] = 'Alab A&M'
# x.loc[ x["team"] == 'Appalachian State', 'sos'] = 'App State'
# x.loc[ x["team"] == 'Arkansas-Pine Bluff', 'sos'] = 'Ark Pine Bl'
# x.loc[ x["team"] == 'Bethune-Cookman', 'sos'] = 'Beth-Cook'
# x.loc[ x["team"] == 'Boston College', 'sos'] = 'Boston Col'
# x.loc[ x["team"] == 'Bowling Green', 'sos'] = 'Bowling Grn'
# x.loc[ x["team"] == 'Cal State Bakersfield', 'sos'] = 'CS Bakersfld'
# x.loc[ x["team"] == 'Cal State Northridge', 'sos'] = 'Cal St Nrdge'
# x.loc[ x["team"] == 'Central Arkansas', 'sos'] = 'Central Ark'
# x.loc[ x["team"] == 'Central Connecticut State', 'sos'] = 'Central Conn'
# x.loc[ x["team"] == 'Central Michigan', 'sos'] = 'Central Mich'
# x.loc[ x["team"] == 'Charleston', 'sos'] = 'Col Charlestn'
# x.loc[ x["team"] == 'Charleston Southern', 'sos'] = 'Charl South'
# x.loc[ x["team"] == 'Coastal Carolina', 'sos'] = 'Coastal Car'
# x.loc[ x["team"] == 'Delaware State', 'sos'] = 'Delaware St'
# x.loc[ x["team"] == 'East Carolina', 'sos'] = 'E Carolina'
# x.loc[ x["team"] == 'East Tennessee State', 'sos'] = 'E Tenn St'
# x.loc[ x["team"] == 'Eastern Illinois', 'sos'] = 'E Illinois'
# x.loc[ x["team"] == 'Eastern Kentucky', 'sos'] = 'E Kentucky'
# x.loc[ x["team"] == 'Eastern Michigan', 'sos'] = 'E Michigan'
# x.loc[ x["team"] == 'Eastern Washington', 'sos'] = 'E Washingtn'
# x.loc[ x["team"] == 'Fairleigh Dickinson', 'sos'] = 'F Dickinson'
# x.loc[ x["team"] == 'Florida Atlantic', 'sos'] = 'Fla Atlantic'
# x.loc[ x["team"] == 'Florida Gulf Coast', 'sos'] = 'Fla Gulf Cst'
# x.loc[ x["team"] == 'Florida International', 'sos'] = 'Florida Intl'
# x.loc[ x["team"] == 'Gardner-Webb', 'sos'] = 'Gard-Webb'
# x.loc[ x["team"] == 'George Mason', 'sos'] = 'Geo Mason'
# x.loc[ x["team"] == 'George Washington', 'sos'] = 'Geo Wshgtn'
# x.loc[ x["team"] == 'Georgia Southern', 'sos'] = 'GA Southern'
# x.loc[ x["team"] == 'Georgia Tech', 'sos'] = 'GA Tech'
# x.loc[ x["team"] == 'Grambling State', 'sos'] = 'Grambling St'
# x.loc[ x["team"] == 'Grand Canyon', 'sos'] = 'Grd Canyon'
# x.loc[ x["team"] == 'Green Bay', 'sos'] = 'WI-Grn Bay'
# x.loc[ x["team"] == 'Houston Christian', 'sos'] = 'Hsn Christian'
# x.loc[ x["team"] == 'Idaho State', 'sos'] = 'Idaho St'
# x.loc[ x["team"] == 'Illinois-Chicago', 'sos'] = 'IL-Chicago'
# x.loc[ x["team"] == 'Incarnate Word', 'sos'] = 'Incar Word'
# x.loc[ x["team"] == 'Jackson State', 'sos'] = 'Jackson St'
# x.loc[ x["team"] == 'California Baptist', 'sos'] = 'Cal Baptist'
# x.loc[ x["team"] == 'Florida A&amp;M', 'sos'] = 'Florida A&M'
# x.loc[ x["team"] == 'Jacksonville State', 'sos'] = 'Jksnville St'
# x.loc[ x["team"] == 'James Madison', 'sos'] = 'James Mad'
# x.loc[ x["team"] == 'Little Rock', 'sos'] = 'AR Lit Rock'
# x.loc[ x["team"] == 'Long Beach State', 'sos'] = 'Lg Beach St'
# x.loc[ x["team"] == 'Louisiana Tech', 'sos'] = 'LA Tech'
# x.loc[ x["team"] == 'Louisiana-Monroe', 'sos'] = 'UL Monroe'
# x.loc[ x["team"] == 'Loyola (IL)', 'sos'] = 'Loyola-Chi'
# x.loc[ x["team"] == 'Loyola (MD)', 'sos'] = 'Loyola-MD'
# x.loc[ x["team"] == 'Loyola Marymount', 'sos'] = 'Loyola Mymt'
# x.loc[ x["team"] == 'Maryland-Eastern Shore', 'sos'] = 'Maryland ES'
# x.loc[ x["team"] == 'Massachusetts', 'sos'] = 'U Mass'
# x.loc[ x["team"] == 'Middle Tennessee State', 'sos'] = 'Middle Tenn'
# x.loc[ x["team"] == 'Milwaukee', 'sos'] = 'WI-Milwkee'
# x.loc[ x["team"] == 'Mississippi State', 'sos'] = 'Miss State'
# x.loc[ x["team"] == 'Mississippi Valley State', 'sos'] = 'Miss Val St'
# x.loc[ x["team"] == 'Mount St. Mary', 'sos'] = 'Mt St Marys'
# x.loc[ x["team"] == 'New Hampshire', 'sos'] = 'N Hampshire'
# x.loc[ x["team"] == 'New Mexico State', 'sos'] = 'N Mex State'
# x.loc[ x["team"] == 'Nicholls State', 'sos'] = 'Nicholls'
# x.loc[ x["team"] == 'Norfolk State', 'sos'] = 'Norfolk St'
# x.loc[ x["team"] == 'North Alabama', 'sos'] = 'N Alabama'
# x.loc[ x["team"] == 'North Carolina', 'sos'] = 'N Carolina'
# x.loc[ x["team"] == 'North Dakota State', 'sos'] = 'N Dakota St'
# x.loc[ x["team"] == 'North Florida', 'sos'] = 'N Florida'
# x.loc[ x["team"] == 'Northeastern', 'sos'] = 'Northeastrn'
# x.loc[ x["team"] == 'Northern Arizona', 'sos'] = 'N Arizona'
# x.loc[ x["team"] == 'Northern Colorado', 'sos'] = 'N Colorado'
# x.loc[ x["team"] == 'Northern Illinois', 'sos'] = 'N Illinois'
# x.loc[ x["team"] == 'Northern Iowa', 'sos'] = 'N Iowa'
# x.loc[ x["team"] == 'Northern Kentucky', 'sos'] = 'N Kentucky'
# x.loc[ x["team"] == 'Northwestern State', 'sos'] = 'NW State'
# x.loc[ x["team"] == 'Omaha', 'sos'] = 'Neb Omaha'
# x.loc[ x["team"] == 'Pennsylvania', 'sos'] = 'U Penn'
# x.loc[ x["team"] == 'Robert Morris', 'sos'] = 'Rob Morris'
# x.loc[ x["team"] == 'SIU-Edwardsville', 'sos'] = 'SIU Edward'
# x.loc[ x["team"] == 'Sacramento State', 'sos'] = 'Sac State'
# x.loc[ x["team"] == 'Sacred Heart', 'sos'] = 'Sacred Hrt'
# x.loc[ x["team"] == 'Sam Houston State', 'sos'] = 'Sam Hous St'
# x.loc[ x["team"] == 'South Alabama', 'sos'] = 'S Alabama'
# x.loc[ x["team"] == 'South Carolina', 'sos'] = 'S Carolina'
# x.loc[ x["team"] == 'South Carolina State', 'sos'] = 'S Car State'
# x.loc[ x["team"] == 'South Dakota State', 'sos'] = 'S Dakota St'
# x.loc[ x["team"] == 'South Florida', 'sos'] = 'S Florida'
# x.loc[ x["team"] == 'Southeast Missouri State', 'sos'] = 'SE Missouri'
# x.loc[ x["team"] == 'Southern Illinois', 'sos'] = 'S Illinois'
# x.loc[ x["team"] == 'Southern Indiana', 'sos'] = 'S Indiana'
# x.loc[ x["team"] == 'Southern Methodist', 'sos'] = 'S Methodist'
# x.loc[ x["team"] == 'Southern Mississippi', 'sos'] = 'S Mississippi'
# x.loc[ x["team"] == 'Southern Utah', 'sos'] = 'S Utah'
# x.loc[ x["team"] == 'St. Bonaventure', 'sos'] = 'St Bonavent'
# x.loc[ x["team"] == 'St. Francis (PA)', 'sos'] = 'St Fran (PA)'
# x.loc[ x["team"] == 'St. Thomas-Minnesota', 'sos'] = 'St. Thomas'
# x.loc[ x["team"] == 'Stephen F. Austin', 'sos'] = 'Ste F Austin'
# x.loc[ x["team"] == 'TCU', 'sos'] = 'TX Christian'
# x.loc[ x["team"] == 'Tennessee State', 'sos'] = 'TN State'
# x.loc[ x["team"] == 'Tennessee Tech', 'sos'] = 'TN Tech'
# x.loc[ x["team"] == 'Tennessee-Martin', 'sos'] = 'TN Martin'
# x.loc[ x["team"] == 'Texas A&amp;M Commerce', 'sos'] = 'TX A&M-Com'
# x.loc[ x["team"] == 'Texas Southern', 'sos'] = 'TX Southern'
# x.loc[ x["team"] == 'Texas State', 'sos'] = 'Texas St'
# x.loc[ x["team"] == 'Texas Tech', 'sos'] = 'Texas Tech'
# x.loc[ x["team"] == 'Texas-Arlington', 'sos'] = 'TX-Arlington'
# x.loc[ x["team"] == 'Texas-RGV', 'sos'] = 'TX-Pan Am'
# x.loc[ x["team"] == 'UMBC', 'sos'] = 'Maryland BC'
# x.loc[ x["team"] == 'UMKC', 'sos'] = 'Kansas City'
# x.loc[ x["team"] == 'UMass Lowell', 'sos'] = 'Mass Lowell'
# x.loc[ x["team"] == 'UNC Asheville', 'sos'] = 'NC-Asheville'
# x.loc[ x["team"] == 'UNC Greensboro', 'sos'] = 'NC-Grnsboro'
# x.loc[ x["team"] == 'UNC Wilmington', 'sos'] = 'NC-Wilmgton'
# x.loc[ x["team"] == 'USC Upstate', 'sos'] = 'SC Upstate'
# x.loc[ x["team"] == 'UTEP', 'sos'] = 'TX El Paso'
# x.loc[ x["team"] == 'Virginia Tech', 'sos'] = 'VA Tech'
# x.loc[ x["team"] == 'Washington State', 'sos'] = 'Wash State'
# x.loc[ x["team"] == 'Western Carolina', 'sos'] = 'W Carolina'
# x.loc[ x["team"] == 'Western Illinois', 'sos'] = 'W Illinois'
# x.loc[ x["team"] == 'Western Kentucky', 'sos'] = 'W Kentucky'
# x.loc[ x["team"] == 'Western Michigan', 'sos'] = 'W Michigan'
# x.loc[ x["team"] == 'West Virginia', 'sos'] = 'W Virginia'
# x.loc[ x["team"] == 'William &amp; Mary', 'sos'] = 'Wm & Mary'
# x.loc[ x["team"] == 'Youngstown State', 'sos'] = 'Youngs St'

# %%
#DAILY SCORES E1

# import pandas as pd
# from bs4 import BeautifulSoup
# import requests
# import re
# import numpy as np
# from openpyxl import load_workbook

# x = pd.read_csv('abbreviations.csv')
# x['sportsref'] = np.nan

# dailyscores = pd.DataFrame()
# e1 = pd.read_pickle('data.pkl')
# # e1.drop(['Unnamed: 0', 'Actual_Spread', 'User_Diff', 'FD_Diff'], axis = 1, inplace=True)
# dates = e1[pd.isna(e1['Away_Actual']) == True].groupby('date')

# for name, group in dates:
#     d = re.findall('\d+', str(name))[:3]
#     s = 'https://www.sports-reference.com/cbb/boxscores/index.cgi?month=%s&day=%s&year=%s' % (d[1], d[2], d[0])
#     url = requests.get(s)
#     parse = BeautifulSoup(url.text, "lxml").prettify()
#     start = [i for i in range(len(parse)) if parse.startswith("<table", i)]
#     end = [i for i in range(len(parse)) if parse.startswith("</table", i)]
#     for i in range(0, len(start)):
#         scores = pd.read_html(parse[start[i]:end[i]+8])[0]
#         scores.columns = ['Team', 'Score', 'Drop']
#         scores['Team'] = scores['Team'].astype(str)
#         scores['Team'] = scores['Team'].apply(lambda x: re.split(' \(\d+\)', x)[0])
#         scores.drop('Drop', axis = 1, inplace=True)
#         scores['m'] = scores.iloc[-1, 1]
#         scores = scores[(scores['Team'] != "Women's") & (scores['Team'] != "Men's")]
#         scores = pd.concat([scores, scores.iloc[::-1].reset_index()], axis = 1)
#         scores.columns = ['Away', 'Away_Score', 'Drop0', 'Drop1', 'Home', 'Home_Score', 'M']
#         scores.drop(['Drop0', 'Drop1'], axis = 1, inplace=True)
#         scores = scores[:-1]
#         dailyscores = pd.concat([dailyscores, scores])
#     x = x.merge(dailyscores['Away'], how='left', left_on='team', right_on='Away')
#     x['sportsref'] = x['sportsref'].fillna(x['Away'])
#     x.drop('Away', axis = 1, inplace = True)
#     x = x.merge(dailyscores['Away'], how='left', left_on='abr', right_on='Away')
#     x['sportsref'] = x['sportsref'].fillna(x['Away'])
#     x.drop('Away', axis = 1, inplace = True)
#     x = x.merge(dailyscores['Away'], how='left', left_on='line', right_on='Away')
#     x['sportsref'] = x['sportsref'].fillna(x['Away'])
#     x.drop('Away', axis = 1, inplace = True)
#     x = x.merge(dailyscores['Away'], how='left', left_on='tor', right_on='Away')
#     x['sportsref'] = x['sportsref'].fillna(x['Away'])
#     x.drop('Away', axis = 1, inplace = True)
#     x = x.merge(dailyscores['Away'], how='left', left_on='hca', right_on='Away')
#     x['sportsref'] = x['sportsref'].fillna(x['Away'])
#     x.drop('Away', axis = 1, inplace = True)
#     x = x.merge(dailyscores['Home'], how='left', left_on='team', right_on='Home')
#     x['sportsref'] = x['sportsref'].fillna(x['Home'])
#     x.drop('Home', axis = 1, inplace = True)
#     x = x.merge(dailyscores['Home'], how='left', left_on='abr', right_on='Home')
#     x['sportsref'] = x['sportsref'].fillna(x['Home'])
#     x.drop('Home', axis = 1, inplace = True)
#     x = x.merge(dailyscores['Home'], how='left', left_on='line', right_on='Home')
#     x['sportsref'] = x['sportsref'].fillna(x['Home'])
#     x.drop('Home', axis = 1, inplace = True)
#     x = x.merge(dailyscores['Home'], how='left', left_on='tor', right_on='Home')
#     x['sportsref'] = x['sportsref'].fillna(x['Home'])
#     x.drop('Home', axis = 1, inplace = True)
#     x = x.merge(dailyscores['Home'], how='left', left_on='hca', right_on='Home')
#     x['sportsref'] = x['sportsref'].fillna(x['Home'])
#     x.drop('Home', axis = 1, inplace = True)


# x.drop_duplicates(subset='team', inplace=True)
# x.drop('Unnamed: 0', axis = 1, inplace = True)
# dailyscores = dailyscores[dailyscores['M'] == "Men's"]
# dailyscores.reset_index(inplace=True)
# dailyscores.drop('index', axis = 1, inplace = True)

# e1 = e1.merge(dailyscores, how='left', left_on=['Away', 'Home'], right_on=['Away', 'Home'])
# e1['Away_Actual'] = e1['Away_Actual'].fillna(e1['Away_Score'])
# e1['Home_Actual'] = e1['Home_Actual'].fillna(e1['Home_Score'])
# e1.drop(['Away_Score', 'Home_Score', 'M'], axis = 1, inplace = True)
# e1.columns

# %%
#INDIVIDUAL PLAYER STATS

# pg = pd.DataFrame()
# i, start = 1, 0
# while start != -1:
#     s = 'https://basketball.realgm.com/ncaa/stats/%s/Averages/Qualified/All/Season/PG/points/desc/%s' % (YEAR, i)
#     url = requests.get(s)
#     parse = BeautifulSoup(url.text, "lxml").prettify()
#     start = parse.find("<table")
#     if start != -1:
#         end = parse.find("</table")
#         temp = pd.read_html(parse[start:end+8])[0]
#         temp.drop(['#'], axis = 1, inplace = True)
#         pg = pd.concat([pg, temp])
#         i+=1
# pg.insert(2, 'Pos', 'PG')    
# pg

# sg = pd.DataFrame()
# i, start = 1, 0
# while start != -1:
#     s = 'https://basketball.realgm.com/ncaa/stats/%s/Averages/Qualified/All/Season/SG/points/desc/%s' % (YEAR, i)
#     url = requests.get(s)
#     parse = BeautifulSoup(url.text, "lxml").prettify()
#     start = parse.find("<table")
#     if start != -1:
#         end = parse.find("</table")
#         temp = pd.read_html(parse[start:end+8])[0]
#         temp.drop(['#'], axis = 1, inplace = True)
#         sg = pd.concat([sg, temp])
#         i+=1
# sg.insert(2, 'Pos', 'SG')    
# sg

# sf = pd.DataFrame()
# i, start = 1, 0
# while start != -1:
#     s = 'https://basketball.realgm.com/ncaa/stats/%s/Averages/Qualified/All/Season/SF/points/desc/%s' % (YEAR, i)
#     url = requests.get(s)
#     parse = BeautifulSoup(url.text, "lxml").prettify()
#     start = parse.find("<table")
#     if start != -1:
#         end = parse.find("</table")
#         temp = pd.read_html(parse[start:end+8])[0]
#         temp.drop(['#'], axis = 1, inplace = True)
#         sf = pd.concat([sf, temp])
#         i+=1
# sf.insert(2, 'Pos', 'SF')    
# sf

# pf = pd.DataFrame()
# i, start = 1, 0
# while start != -1:
#     s = 'https://basketball.realgm.com/ncaa/stats/%s/Averages/Qualified/All/Season/PF/points/desc/%s' % (YEAR, i)
#     url = requests.get(s)
#     parse = BeautifulSoup(url.text, "lxml").prettify()
#     start = parse.find("<table")
#     if start != -1:
#         end = parse.find("</table")
#         temp = pd.read_html(parse[start:end+8])[0]
#         temp.drop(['#'], axis = 1, inplace = True)
#         pf = pd.concat([pf, temp])
#         i+=1
# pf.insert(2, 'Pos', 'PF')    
# pf

# c = pd.DataFrame()
# i, start = 1, 0
# while start != -1:
#     s = 'https://basketball.realgm.com/ncaa/stats/%s/Averages/Qualified/All/Season/C/points/desc/%s' % (YEAR, i)
#     url = requests.get(s)
#     parse = BeautifulSoup(url.text, "lxml").prettify()
#     start = parse.find("<table")
#     if start != -1:
#         end = parse.find("</table")
#         temp = pd.read_html(parse[start:end+8])[0]
#         temp.drop(['#'], axis = 1, inplace = True)
#         c = pd.concat([c, temp])
#         i+=1
# c.insert(2, 'Pos', 'C')    
# c

# players = pd.concat([pg, sg, sf, pf, c])
# players.to_csv('players.csv')

# %%
#FORMAT STATS AS FLOATS

# stats[['GP_x', 'MPG_x', 'PPG_x', 'FGM_x',
#        'FGA_x', 'FG%_x', '3PM_x', '3PA_x', '3P%_x', 'FTM_x',
#        'FTA_x', 'FT%_x', 'ORB_x', 'DRB_x', 'RPG_x', 'APG_x',
#        'SPG_x', 'BPG_x', 'TOV_x', 'PF_x', 'GP_y', 'MPG_y',
#        'PPG_y', 'FGM_y', 'FGA_y', 'FG%_y', '3PM_y', '3PA_y',
#        '3P%_y', 'FTM_y', 'FTA_y', 'FT%_y', 'ORB_y', 'DRB_y',
#        'RPG_y', 'APG_y', 'SPG_y', 'BPG_y', 'TOV_y', 'PF_y', 'Rk',
#        'G', 'AdjOE', 'AdjDE', 'Barthag', 'EFG%', 'EFGD%', 'TOR',
#        'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P%', '2P%D', '3P%', '3P%D',
#        '3PR', '3PRD', 'Adj T.', 'WAB']] = stats[['GP_x', 'MPG_x', 'PPG_x', 'FGM_x',
#        'FGA_x', 'FG%_x', '3PM_x', '3PA_x', '3P%_x', 'FTM_x',
#        'FTA_x', 'FT%_x', 'ORB_x', 'DRB_x', 'RPG_x', 'APG_x',
#        'SPG_x', 'BPG_x', 'TOV_x', 'PF_x', 'GP_y', 'MPG_y',
#        'PPG_y', 'FGM_y', 'FGA_y', 'FG%_y', '3PM_y', '3PA_y',
#        '3P%_y', 'FTM_y', 'FTA_y', 'FT%_y', 'ORB_y', 'DRB_y',
#        'RPG_y', 'APG_y', 'SPG_y', 'BPG_y', 'TOV_y', 'PF_y', 'Rk',
#        'G', 'AdjOE', 'AdjDE', 'Barthag', 'EFG%', 'EFGD%', 'TOR',
#        'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P%', '2P%D', '3P%', '3P%D',
#        '3PR', '3PRD', 'Adj T.', 'WAB']].astype(float)

# %%
#NEW EQUATION DATAFRAME

# import pandas as pd
# e1 = pd.read_pickle('Equation1.pkl')
# e4 = pd.DataFrame(columns = e1.columns)
# e4.to_pickle('Equation31.pkl')
# e4.to_pickle('backupe31.pkl')
# e4.to_pickle('SecondaryEquation31.pkl')
# e4
# Out:
# Empty DataFrame
# Columns: [date, Away, Away_team, Away_abr, Away_line, Away_tor, Away_hca, Away_sportsref, Away_sos, Away_Conf, Away_Record, Away_Spread, Away_odds, Home, Home_team, Home_abr, Home_line, Home_tor, Home_hca, Home_sportsref, Home_sos, Home_Conf, Home_Record, Home_Spread, Home_odds, Predicted_Away_Score, Predicted_Home_Score, Predicted_Spread, bet, bet_by, Away_Actual, Home_Actual, Actual_Spread, User_Diff, FD_Diff, More_Accurate, Result, Hit]
# Index: []
#
# [0 rows x 38 columns]

# %%
#ADD TO LINE ABBREVIATION

# x = pd.read_csv('abbreviations.csv')
# x.drop('Unnamed: 0', axis = 1, inplace=True)
# x[x['team'].str.contains('Bet') == True]

# x.loc[x['team'] == 'Southeast Missouri State', ['line']] = "SE Missouri St."
# x.to_csv('abbreviations.csv')
# x[x['team'].str.contains('Southeast Missouri State') == True]


# x['team'] = x['team'].astype(str)
# x = x.merge(temp, how='left', left_on='team', right_on='Team')
# x['line'] = x['line'].fillna(x['Team'])
# x = x[['team', 'abr', 'line', 'tor', 'hca', 'sportsref']]
# x = x.merge(temp, how='left', left_on='tor', right_on='Team')
# x['line'] = x['line'].fillna(x['Team'])
# x = x[['team', 'abr', 'line', 'tor', 'hca', 'sportsref']]
# x[pd.isna(x['line']) == False].sort_values('team', ascending=True)
# x.to_csv('abbreviations.csv')

# %%
#EMPTY SCORES BY DATE

# e1[(e1['date']!=date(2024, 1, 4)) & (e1['Away_Actual']!=e1['Away_Actual'])][['date', 'Away', 'Home', 'Away_Actual', 'Home_Actual']]

# %%
#ADD CALCULATED COLUMNS

# pd.set_option('display.max_columns', None)
# import math
# e2whole = pd.read_pickle('Equation2.pkl')
# e2 = e2whole[pd.isna(e2whole['Home_Actual']) == False].reset_index().drop('index', axis=1)

# e2[['Actual_Spread', 'Home_Actual', 'Away_Actual']] = e2[['Actual_Spread', 'Home_Actual', 'Away_Actual']].astype(float)
# e2['Actual_Spread'] = e2['Away_Actual'] - e2['Home_Actual']
# e2['User_Diff'] = abs(e2['Predicted_Spread'] - e2['Actual_Spread'])
# e2['FD_Diff'] = abs(e2['Home_Spread'].astype(float) - e2['Actual_Spread'])
# e2['More_Accurate'] = e2['User_Diff'] < e2['FD_Diff']

# result = [] 
# for index, row in e2.iterrows():
#     if row['Actual_Spread'] < 0:
#         if float(row['Home_Spread']) < 0:
#             # Double Neg
#             if row['Actual_Spread'] < float(row['Home_Spread']):
#                 result.append('Home')
#             elif row['Actual_Spread'] > float(row['Home_Spread']):
#                 result.append('Away')
#             else:
#                 result.append('Push')   
#         else:
#             # Mine Neg FD Pos
#             result.append('Home')
#     elif row['Actual_Spread'] > 0:
#         if float(row['Home_Spread']) > 0:
#             # Double Pos
#             if row['Actual_Spread'] > float(row['Home_Spread']):
#                 result.append('Away')
#             elif row['Actual_Spread'] < float(row['Home_Spread']):
#                 result.append('Home') 
#             else:
#                 result.append('Push')
#         else:
#             # Mine Pos FD Neg
#             result.append('Away')
#     else:
#         if float(row['Home_Spread']) < 0:
#            result.append('Away')
#         elif float(row['Home_Spread']) > 0:
#            result.append('Home')
#         else: 
#            result.append('Push')
# e2['Result'] = result
# e2['Hit'] = e2['bet'] == e2['Result']

# e2 = pd.concat([e2, e2whole[pd.isna(e2whole['Home_Actual']) == True].reset_index().drop('index', axis=1)]).reset_index().drop('index', axis=1)
# e2#['Hit'].value_counts()

# %%
#RESTORE BACKUPS

# e1 = pd.read_pickle('backupe1.pkl')
# e2 = pd.read_pickle('backupe2.pkl')
# e3 = pd.read_pickle('backupe3.pkl')
# e4 = pd.read_pickle('backupe4.pkl')

# e1.to_pickle('Equation1.pkl')
# e2.to_pickle('Equation2.pkl')
# e3.to_pickle('Equation3.pkl')
# e4.to_pickle('Equation4.pkl')

# %%
    #FILLS NA FOR SPORTSREF

    # x = x.merge(dailyscores['Away'], how='left', left_on='team', right_on='Away')
    # x['sportsref'] = x['sportsref'].fillna(x['Away'])
    # x.drop('Away', axis = 1, inplace = True)
    # x = x.merge(dailyscores['Away'], how='left', left_on='abr', right_on='Away')
    # x['sportsref'] = x['sportsref'].fillna(x['Away'])
    # x.drop('Away', axis = 1, inplace = True)
    # x = x.merge(dailyscores['Away'], how='left', left_on='line', right_on='Away')
    # x['sportsref'] = x['sportsref'].fillna(x['Away'])
    # x.drop('Away', axis = 1, inplace = True)
    # x = x.merge(dailyscores['Away'], how='left', left_on='tor', right_on='Away')
    # x['sportsref'] = x['sportsref'].fillna(x['Away'])
    # x.drop('Away', axis = 1, inplace = True)
    # x = x.merge(dailyscores['Away'], how='left', left_on='hca', right_on='Away')
    # x['sportsref'] = x['sportsref'].fillna(x['Away'])
    # x.drop('Away', axis = 1, inplace = True)
    # x = x.merge(dailyscores['Home'], how='left', left_on='team', right_on='Home')
    # x['sportsref'] = x['sportsref'].fillna(x['Home'])
    # x.drop('Home', axis = 1, inplace = True)
    # x = x.merge(dailyscores['Home'], how='left', left_on='abr', right_on='Home')
    # x['sportsref'] = x['sportsref'].fillna(x['Home'])
    # x.drop('Home', axis = 1, inplace = True)
    # x = x.merge(dailyscores['Home'], how='left', left_on='line', right_on='Home')
    # x['sportsref'] = x['sportsref'].fillna(x['Home'])
    # x.drop('Home', axis = 1, inplace = True)
    # x = x.merge(dailyscores['Home'], how='left', left_on='tor', right_on='Home')
    # x['sportsref'] = x['sportsref'].fillna(x['Home'])
    # x.drop('Home', axis = 1, inplace = True)
    # x = x.merge(dailyscores['Home'], how='left', left_on='hca', right_on='Home')
    # x['sportsref'] = x['sportsref'].fillna(x['Home'])
    # x.drop('Home', axis = 1, inplace = True)

# %%
# SCORE TESTING

SHOT_POS = 60
YEAR = 2024
POS = 72
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re
import numpy as np
from datetime import date
from datetime import timedelta
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
stats = pd.read_csv('stats.csv')
x = pd.read_csv('abbreviations.csv')
stats = stats.merge(x, how='left', left_on='team', right_on='team')

h = stats[stats['team'] == 'Baylor']
a = stats[stats['team'] == 'Lehigh']
h_pos = SHOT_POS * ((((h.iloc[0]['3P%'] + a.iloc[0]['3P%D'])) / 100) + (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD'])) / 100))
a_pos = SHOT_POS * ((((a.iloc[0]['3P%'] + h.iloc[0]['3P%D'])) / 100) + (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD'])) / 100))
home =  (((((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) * (((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100)) * (h_pos * 3)) + ((((h.iloc[0]['FTR'] + a.iloc[0]['FTRD']) / (2)) / 100) * (h.iloc[0]['FT%_x']) * (h_pos * 1)) + ((1 - (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) + (((h.iloc[0]['FTR'] + a.iloc[0]['FTRD']) / (2*2)) / 100)) * (((h.iloc[0]['2P%'] + a.iloc[0]['2P%D']) / 2) / 100) * (h_pos * 2)) + h.iloc[0]['HC_ADV'] + h.iloc[0]['SOS']
away = (((((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) * (((a.iloc[0]['3P%'] + h.iloc[0]['3P%D']) / 2) / 100)) * (a_pos * 3)) + ((((a.iloc[0]['FTR'] + h.iloc[0]['FTRD']) / (2)) / 100) * (a.iloc[0]['FT%_x']) * (a_pos * 1)) + ((1 - (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) + (((a.iloc[0]['FTR'] + h.iloc[0]['FTRD']) / (2*2)) / 100)) * (((a.iloc[0]['2P%'] + h.iloc[0]['2P%D']) / 2) / 100) * (a_pos * 2)) + a.iloc[0]['SOS']

print('Score: ' + a.iloc[0]['team'] + ' ' + str(round(a_pos, 2)) + ' @ ' + h.iloc[0]['team'] + ' ' +  str(round(h_pos, 2)) + ' TOTAL: ' + str(round(home + away, 2)) + ', ' + str(round(away - home, 2)))
#  (((((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) * (((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100)) * (72 * 3)) + ((((h.iloc[0]['FTR'] + a.iloc[0]['FTRD']) / (2)) / 100) * (h.iloc[0]['FT%_x']) * (72 * 1))
# Out:
# Score: Lehigh 78.9 @ Baylor 92.04 TOTAL: 256.7, -49.86

# %%
#EMPTY DAILYSCORES

# YEAR = 2024
# POS = 72
# import pandas as pd
# from bs4 import BeautifulSoup
# import requests
# import re
# import numpy as np
# from datetime import date
# from datetime import timedelta
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.support.wait import WebDriverWait

# dailyscores = pd.DataFrame()
# x = pd.read_csv('abbreviations.csv')
# x.drop('Unnamed: 0', axis=1, inplace=True)

# s = 'https://www.sports-reference.com/cbb/boxscores/index.cgi?month=%s&day=%s&year=%s' % (1, 5, 2024)
# url = requests.get(s)
# parse = BeautifulSoup(url.text, "lxml").prettify()
# start = [i for i in range(len(parse)) if parse.startswith("<table", i)]
# end = [i for i in range(len(parse)) if parse.startswith("</table", i)]
# for i in range(0, len(start)):
#     scores = pd.read_html(parse[start[i]:end[i]+8])[0]
#     scores.columns = ['Team', 'Score', 'Drop']
#     scores['Team'] = scores['Team'].astype(str)
#     scores['Team'] = scores['Team'].apply(lambda x: re.split(' \(\d+\)', x)[0])
#     scores['Team'] = scores['Team'].apply(lambda x: x[:-1] if x[-1:] == ' ' else x)
#     scores.drop('Drop', axis = 1, inplace=True)
#     scores['m'] = scores.iloc[-1, 1]
#     scores = scores[(scores['Team'] != "Women's") & (scores['Team'] != "Men's")]
#     scores = pd.concat([scores, scores.iloc[::-1].reset_index()], axis = 1)
#     scores.columns = ['Away', 'Away_Score', 'Drop0', 'Drop1', 'Home', 'Home_Score', 'M']
#     scores.drop(['Drop0', 'Drop1'], axis = 1, inplace=True)
#     scores = scores[:-1]
#     dailyscores = pd.concat([dailyscores, scores])
# x = x.merge(dailyscores['Away'], how='left', left_on='team', right_on='Away')
# x['sportsref'] = x['sportsref'].fillna(x['Away'])
# x.drop('Away', axis = 1, inplace = True)
# x = x.merge(dailyscores['Away'], how='left', left_on='abr', right_on='Away')
# x['sportsref'] = x['sportsref'].fillna(x['Away'])
# x.drop('Away', axis = 1, inplace = True)
# x = x.merge(dailyscores['Away'], how='left', left_on='line', right_on='Away')
# x['sportsref'] = x['sportsref'].fillna(x['Away'])
# x.drop('Away', axis = 1, inplace = True)
# x = x.merge(dailyscores['Away'], how='left', left_on='tor', right_on='Away')
# x['sportsref'] = x['sportsref'].fillna(x['Away'])
# x.drop('Away', axis = 1, inplace = True)
# x = x.merge(dailyscores['Away'], how='left', left_on='hca', right_on='Away')
# x['sportsref'] = x['sportsref'].fillna(x['Away'])
# x.drop('Away', axis = 1, inplace = True)
# x = x.merge(dailyscores['Home'], how='left', left_on='team', right_on='Home')
# x['sportsref'] = x['sportsref'].fillna(x['Home'])
# x.drop('Home', axis = 1, inplace = True)
# x = x.merge(dailyscores['Home'], how='left', left_on='abr', right_on='Home')
# x['sportsref'] = x['sportsref'].fillna(x['Home'])
# x.drop('Home', axis = 1, inplace = True)
# x = x.merge(dailyscores['Home'], how='left', left_on='line', right_on='Home')
# x['sportsref'] = x['sportsref'].fillna(x['Home'])
# x.drop('Home', axis = 1, inplace = True)
# x = x.merge(dailyscores['Home'], how='left', left_on='tor', right_on='Home')
# x['sportsref'] = x['sportsref'].fillna(x['Home'])
# x.drop('Home', axis = 1, inplace = True)
# x = x.merge(dailyscores['Home'], how='left', left_on='hca', right_on='Home')
# x['sportsref'] = x['sportsref'].fillna(x['Home'])
# x.drop('Home', axis = 1, inplace = True)

# dailyscores = dailyscores.merge(x, how='left', left_on='Away', right_on='sportsref')
# dailyscores.drop(['M', 'team', 'abr', 'line', 'tor', 'hca'], axis = 1, inplace = True)
# dailyscores.rename({'sportsref':'Away_sportsref'}, axis = 1, inplace=True)

# dailyscores = dailyscores.merge(x, how='left', left_on='Home', right_on='sportsref')
# dailyscores.drop(['team', 'abr', 'line', 'tor', 'hca'], axis = 1, inplace = True)
# dailyscores.rename({'sportsref':'Home_sportsref'}, axis = 1, inplace=True)

# dailyscores.drop_duplicates(inplace=True)

# dailyscores[(dailyscores['Away_sportsref'] != dailyscores['Away_sportsref']) | (dailyscores['Home_sportsref'] != dailyscores['Home_sportsref'])]
# dailyscores

# %%
#SET EMPTY ABBREVIATION

# x = pd.read_csv('abbreviations.csv')
# x.drop('Unnamed: 0', axis = 1, inplace=True)
# x[x['team'].str.contains('Conn') == True]

# x.loc[x['team'] == 'Bowling Green', ['sportsref']] = "Bowling Green State"
# x.to_csv('abbreviations.csv')
# x[x['team'].str.contains('Bowling Green') == True]

# %%
#ORIGINAL CODE

# YEAR = 2024
# POS = 72
# SHOT_POS = 60
# import pandas as pd
# from bs4 import BeautifulSoup
# import requests
# import re
# import numpy as np
# import math
# from datetime import date
# from datetime import timedelta
# from selenium import webdriver
# from selenium.webdriver.common.by import By
# from selenium.webdriver.support.wait import WebDriverWait

# #Import data
# x = pd.read_csv('abbreviations.csv')
# x.drop('Unnamed: 0', axis=1, inplace=True)
# e1 = pd.read_pickle('Equation1.pkl')
# e2 = pd.read_pickle('Equation2.pkl')
# e3 = pd.read_pickle('Equation3.pkl')
# e4 = pd.read_pickle('Equation4.pkl')
# e5 = pd.read_pickle('Equation5.pkl')
# e6 = pd.read_pickle('Equation6.pkl')
# e7 = pd.read_pickle('Equation7.pkl')
# e8 = pd.read_pickle('Equation8.pkl')
# e9 = pd.read_pickle('Equation9.pkl')
# e10 = pd.read_pickle('Equation10.pkl')

# #Get dates with missing scores
# e1Missing = e1[pd.isna(e1['Home_Actual']) == True]
# dailyscores = pd.DataFrame()
# dates = e1Missing[pd.isna(e1Missing['Away_Actual']) == True].groupby('date')

# #Itterate through missing dates
# for name, group in dates:
#     #Gets M, D, Y from name (date)
#     d = re.findall('\d+', str(name))[:3]
#     #Gets scores for date found
#     s = 'https://www.sports-reference.com/cbb/boxscores/index.cgi?month=%s&day=%s&year=%s' % (d[1], d[2], d[0])
#     url = requests.get(s)
#     parse = BeautifulSoup(url.text, "lxml").prettify()
#     start = [i for i in range(len(parse)) if parse.startswith("<table", i)]
#     end = [i for i in range(len(parse)) if parse.startswith("</table", i)]
#     #Itterate through row in missing games per date
#     for i in range(0, len(start)):
#         #Gets one Score, then prepares the data
#         scores = pd.read_html(parse[start[i]:end[i]+8])[0]
#         scores.columns = ['Team', 'Score', 'Drop']
#         scores['Team'] = scores['Team'].astype(str)
#         scores['Team'] = scores['Team'].apply(lambda x: re.split(' \(\d+\)', x)[0])
#         scores['Team'] = scores['Team'].apply(lambda x: x[:-1] if x[-1:] == ' ' else x)
#         scores.drop('Drop', axis = 1, inplace=True)
#         scores['m'] = scores.iloc[-1, 1]
#         scores = scores[(scores['Team'] != "Women's") & (scores['Team'] != "Men's")]
#         scores = pd.concat([scores, scores.iloc[::-1].reset_index()], axis = 1)
#         scores.columns = ['Away', 'Away_Score', 'Drop0', 'Drop1', 'Home', 'Home_Score', 'M']
#         scores.drop(['Drop0', 'Drop1'], axis = 1, inplace=True)
#         scores = scores[:-1]
#         #Adds each individual score to a runnning chart for the day
#         dailyscores = pd.concat([dailyscores, scores])

# #Makes sure games are played today
# if not dailyscores.empty:
#     x.drop_duplicates(subset='team', inplace=True)
#     x.to_csv('abbreviations.csv')

#     #For each formula and game, add the sportsref to the DF
#     e1 = e1.merge(x, how='left', left_on='Away', right_on='line')
#     e1['Away_sportsref'] = e1['Away_sportsref'].fillna(e1['sportsref'])
#     e1.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e1.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e1 = e1.merge(x, how='left', left_on='Home', right_on='line')
#     e1['Home_sportsref'] = e1['Home_sportsref'].fillna(e1['sportsref'])
#     e1.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e1.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e2 = e2.merge(x, how='left', left_on='Away', right_on='line')
#     e2['Away_sportsref'] = e2['Away_sportsref'].fillna(e2['sportsref'])
#     e2.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e2.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e2 = e2.merge(x, how='left', left_on='Home', right_on='line')
#     e2['Home_sportsref'] = e2['Home_sportsref'].fillna(e2['sportsref'])
#     e2.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e2.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e3 = e3.merge(x, how='left', left_on='Away', right_on='line')
#     e3['Away_sportsref'] = e3['Away_sportsref'].fillna(e3['sportsref'])
#     e3.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e3.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e3 = e3.merge(x, how='left', left_on='Home', right_on='line')
#     e3['Home_sportsref'] = e3['Home_sportsref'].fillna(e3['sportsref'])
#     e3.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e3.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e4 = e4.merge(x, how='left', left_on='Away', right_on='line')
#     e4['Away_sportsref'] = e4['Away_sportsref'].fillna(e4['sportsref'])
#     e4.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e4.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e4 = e4.merge(x, how='left', left_on='Home', right_on='line')
#     e4['Home_sportsref'] = e4['Home_sportsref'].fillna(e4['sportsref'])
#     e4.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e4.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e5 = e5.merge(x, how='left', left_on='Away', right_on='line')
#     e5['Away_sportsref'] = e5['Away_sportsref'].fillna(e5['sportsref'])
#     e5.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e5.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e5 = e5.merge(x, how='left', left_on='Home', right_on='line')
#     e5['Home_sportsref'] = e5['Home_sportsref'].fillna(e5['sportsref'])
#     e5.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e5.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e6 = e6.merge(x, how='left', left_on='Away', right_on='line')
#     e6['Away_sportsref'] = e6['Away_sportsref'].fillna(e6['sportsref'])
#     e6.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e6.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e6 = e6.merge(x, how='left', left_on='Home', right_on='line')
#     e6['Home_sportsref'] = e6['Home_sportsref'].fillna(e6['sportsref'])
#     e6.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e6.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e7 = e7.merge(x, how='left', left_on='Away', right_on='line')
#     e7['Away_sportsref'] = e7['Away_sportsref'].fillna(e7['sportsref'])
#     e7.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e7.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e7 = e7.merge(x, how='left', left_on='Home', right_on='line')
#     e7['Home_sportsref'] = e7['Home_sportsref'].fillna(e7['sportsref'])
#     e7.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e7.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e8 = e8.merge(x, how='left', left_on='Away', right_on='line')
#     e8['Away_sportsref'] = e8['Away_sportsref'].fillna(e8['sportsref'])
#     e8.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e8.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e8 = e8.merge(x, how='left', left_on='Home', right_on='line')
#     e8['Home_sportsref'] = e8['Home_sportsref'].fillna(e8['sportsref'])
#     e8.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e8.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e9 = e9.merge(x, how='left', left_on='Away', right_on='line')
#     e9['Away_sportsref'] = e9['Away_sportsref'].fillna(e9['sportsref'])
#     e9.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e9.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e9 = e9.merge(x, how='left', left_on='Home', right_on='line')
#     e9['Home_sportsref'] = e9['Home_sportsref'].fillna(e9['sportsref'])
#     e9.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e9.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e10 = e10.merge(x, how='left', left_on='Away', right_on='line')
#     e10['Away_sportsref'] = e10['Away_sportsref'].fillna(e10['sportsref'])
#     e10.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e10.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)
#     e10 = e10.merge(x, how='left', left_on='Home', right_on='line')
#     e10['Home_sportsref'] = e10['Home_sportsref'].fillna(e10['sportsref'])
#     e10.drop(['team','abr','line','tor','hca','sportsref', 'sos'], axis = 1, inplace=True)
#     e10.drop_duplicates(subset=['date', 'Away', 'Home'], inplace=True)

#     #Seperate missing and present data for each formula
#     e1Missing = e1[pd.isna(e1['Home_Actual']) == True]
#     e1Present = e1[pd.isna(e1['Home_Actual']) == False]
#     e2Missing = e2[pd.isna(e2['Home_Actual']) == True]
#     e2Present = e2[pd.isna(e2['Home_Actual']) == False]
#     e3Missing = e3[pd.isna(e3['Home_Actual']) == True]
#     e3Present = e3[pd.isna(e3['Home_Actual']) == False]
#     e4Missing = e4[pd.isna(e4['Home_Actual']) == True]
#     e4Present = e4[pd.isna(e4['Home_Actual']) == False]
#     e5Missing = e5[pd.isna(e5['Home_Actual']) == True]
#     e5Present = e5[pd.isna(e5['Home_Actual']) == False]
#     e6Missing = e6[pd.isna(e6['Home_Actual']) == True]
#     e6Present = e6[pd.isna(e6['Home_Actual']) == False]
#     e7Missing = e7[pd.isna(e7['Home_Actual']) == True]
#     e7Present = e7[pd.isna(e7['Home_Actual']) == False]
#     e8Missing = e8[pd.isna(e8['Home_Actual']) == True]
#     e8Present = e8[pd.isna(e8['Home_Actual']) == False]
#     e9Missing = e9[pd.isna(e9['Home_Actual']) == True]
#     e9Present = e9[pd.isna(e9['Home_Actual']) == False]
#     e10Missing = e10[pd.isna(e10['Home_Actual']) == True]
#     e10Present = e10[pd.isna(e10['Home_Actual']) == False]

#     #Get just men's scores
#     dailyscores = dailyscores[dailyscores['M'] == "Men's"]
#     dailyscores.reset_index(inplace=True)
#     dailyscores.drop('index', axis = 1, inplace = True)

#     #For each formula and game, add the score to the DF
#     e1Missing = e1Missing.merge(dailyscores, how='left', left_on=['Away_sportsref', 'Home_sportsref'], right_on=['Away', 'Home'])
#     e1Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e1Missing['Away_Actual'] = e1Missing['Away_Actual'].fillna(e1Missing['Away_Score'])
#     e1Missing['Home_Actual'] = e1Missing['Home_Actual'].fillna(e1Missing['Home_Score'])
#     e1Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)
#     e1Missing = e1Missing.merge(dailyscores, how='left', left_on=['Home_sportsref', 'Away_sportsref'], right_on=['Away', 'Home'])
#     e1Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e1Missing['Away_Actual'] = e1Missing['Away_Actual'].fillna(e1Missing['Home_Score'])
#     e1Missing['Home_Actual'] = e1Missing['Home_Actual'].fillna(e1Missing['Away_Score'])
#     e1Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)

#     #Fill in missing calculated fields, then re-combine missing and present
#     e1Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']] = e1Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']].astype(float)
#     e1Missing['Actual_Spread'] = e1Missing['Away_Actual'] - e1Missing['Home_Actual']
#     e1Missing['User_Diff'] = abs(e1Missing['Predicted_Spread'] - e1Missing['Actual_Spread'])
#     e1Missing['FD_Diff'] = abs(e1Missing['Home_Spread'].astype(float) - e1Missing['Actual_Spread'])
#     e1Missing['More_Accurate'] = e1Missing['User_Diff'] < e1Missing['FD_Diff'] 
#     result = [] 
#     for index, row in e1Missing.iterrows():
#         if row['Actual_Spread'] < 0:
#             if float(row['Home_Spread']) < 0:
#                 # Double Neg
#                 if row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home')
#                 elif row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 else:
#                     result.append('Push')   
#             else:
#                 # Mine Neg FD Pos
#                 result.append('Home')
#         elif row['Actual_Spread'] > 0:
#             if float(row['Home_Spread']) > 0:
#                 # Double Pos
#                 if row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 elif row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home') 
#                 else:
#                     result.append('Push')
#             else:
#                 # Mine Pos FD Neg
#                 result.append('Away')
#         else:
#             if float(row['Home_Spread']) < 0:
#                 result.append('Away')
#             elif float(row['Home_Spread']) > 0:
#                 result.append('Home')
#             else: 
#                 result.append('Push')
#     e1Missing['Result'] = result
#     e1Missing['Hit'] = e1Missing['bet'] == e1Missing['Result']
#     e1 = pd.concat([e1Present, e1Missing])

#     e2Missing = e2Missing.merge(dailyscores, how='left', left_on=['Away_sportsref', 'Home_sportsref'], right_on=['Away', 'Home'])
#     e2Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e2Missing['Away_Actual'] = e2Missing['Away_Actual'].fillna(e2Missing['Away_Score'])
#     e2Missing['Home_Actual'] = e2Missing['Home_Actual'].fillna(e2Missing['Home_Score'])
#     e2Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)
#     e2Missing = e2Missing.merge(dailyscores, how='left', left_on=['Home_sportsref', 'Away_sportsref'], right_on=['Away', 'Home'])
#     e2Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e2Missing['Away_Actual'] = e2Missing['Away_Actual'].fillna(e2Missing['Home_Score'])
#     e2Missing['Home_Actual'] = e2Missing['Home_Actual'].fillna(e2Missing['Away_Score'])
#     e2Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)

#     e2Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']] = e2Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']].astype(float)
#     e2Missing['Actual_Spread'] = e2Missing['Away_Actual'] - e2Missing['Home_Actual']
#     e2Missing['User_Diff'] = abs(e2Missing['Predicted_Spread'] - e2Missing['Actual_Spread'])
#     e2Missing['FD_Diff'] = abs(e2Missing['Home_Spread'].astype(float) - e2Missing['Actual_Spread'])
#     e2Missing['More_Accurate'] = e2Missing['User_Diff'] < e2Missing['FD_Diff'] 
#     result = [] 
#     for index, row in e2Missing.iterrows():
#         if row['Actual_Spread'] < 0:
#             if float(row['Home_Spread']) < 0:
#                 # Double Neg
#                 if row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home')
#                 elif row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 else:
#                     result.append('Push')   
#             else:
#                 # Mine Neg FD Pos
#                 result.append('Home')
#         elif row['Actual_Spread'] > 0:
#             if float(row['Home_Spread']) > 0:
#                 # Double Pos
#                 if row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 elif row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home') 
#                 else:
#                     result.append('Push')
#             else:
#                 # Mine Pos FD Neg
#                 result.append('Away')
#         else:
#             if float(row['Home_Spread']) < 0:
#                 result.append('Away')
#             elif float(row['Home_Spread']) > 0:
#                 result.append('Home')
#             else: 
#                 result.append('Push')
#     e2Missing['Result'] = result
#     e2Missing['Hit'] = e2Missing['bet'] == e2Missing['Result']
#     e2 = pd.concat([e2Present, e2Missing])

#     e3Missing = e3Missing.merge(dailyscores, how='left', left_on=['Away_sportsref', 'Home_sportsref'], right_on=['Away', 'Home'])
#     e3Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e3Missing['Away_Actual'] = e3Missing['Away_Actual'].fillna(e3Missing['Away_Score'])
#     e3Missing['Home_Actual'] = e3Missing['Home_Actual'].fillna(e3Missing['Home_Score'])
#     e3Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)
#     e3Missing = e3Missing.merge(dailyscores, how='left', left_on=['Home_sportsref', 'Away_sportsref'], right_on=['Away', 'Home'])
#     e3Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e3Missing['Away_Actual'] = e3Missing['Away_Actual'].fillna(e3Missing['Home_Score'])
#     e3Missing['Home_Actual'] = e3Missing['Home_Actual'].fillna(e3Missing['Away_Score'])
#     e3Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)
    
#     e3Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']] = e3Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']].astype(float)
#     e3Missing['Actual_Spread'] = e3Missing['Away_Actual'] - e3Missing['Home_Actual']
#     e3Missing['User_Diff'] = abs(e3Missing['Predicted_Spread'] - e3Missing['Actual_Spread'])
#     e3Missing['FD_Diff'] = abs(e3Missing['Home_Spread'].astype(float) - e3Missing['Actual_Spread'])
#     e3Missing['More_Accurate'] = e3Missing['User_Diff'] < e3Missing['FD_Diff'] 
#     result = [] 
#     for index, row in e3Missing.iterrows():
#         if row['Actual_Spread'] < 0:
#             if float(row['Home_Spread']) < 0:
#                 # Double Neg
#                 if row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home')
#                 elif row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 else:
#                     result.append('Push')   
#             else:
#                 # Mine Neg FD Pos
#                 result.append('Home')
#         elif row['Actual_Spread'] > 0:
#             if float(row['Home_Spread']) > 0:
#                 # Double Pos
#                 if row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 elif row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home') 
#                 else:
#                     result.append('Push')
#             else:
#                 # Mine Pos FD Neg
#                 result.append('Away')
#         else:
#             if float(row['Home_Spread']) < 0:
#                 result.append('Away')
#             elif float(row['Home_Spread']) > 0:
#                 result.append('Home')
#             else: 
#                 result.append('Push')
#     e3Missing['Result'] = result
#     e3Missing['Hit'] = e3Missing['bet'] == e3Missing['Result']
#     e3 = pd.concat([e3Present, e3Missing])

#     e4Missing = e4Missing.merge(dailyscores, how='left', left_on=['Away_sportsref', 'Home_sportsref'], right_on=['Away', 'Home'])
#     e4Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e4Missing['Away_Actual'] = e4Missing['Away_Actual'].fillna(e4Missing['Away_Score'])
#     e4Missing['Home_Actual'] = e4Missing['Home_Actual'].fillna(e4Missing['Home_Score'])
#     e4Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)
#     e4Missing = e4Missing.merge(dailyscores, how='left', left_on=['Home_sportsref', 'Away_sportsref'], right_on=['Away', 'Home'])
#     e4Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e4Missing['Away_Actual'] = e4Missing['Away_Actual'].fillna(e4Missing['Home_Score'])
#     e4Missing['Home_Actual'] = e4Missing['Home_Actual'].fillna(e4Missing['Away_Score'])
#     e4Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)
    
#     e4Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']] = e4Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']].astype(float)
#     e4Missing['Actual_Spread'] = e4Missing['Away_Actual'] - e4Missing['Home_Actual']
#     e4Missing['User_Diff'] = abs(e4Missing['Predicted_Spread'] - e4Missing['Actual_Spread'])
#     e4Missing['FD_Diff'] = abs(e4Missing['Home_Spread'].astype(float) - e4Missing['Actual_Spread'])
#     e4Missing['More_Accurate'] = e4Missing['User_Diff'] < e4Missing['FD_Diff'] 
#     result = [] 
#     for index, row in e4Missing.iterrows():
#         if row['Actual_Spread'] < 0:
#             if float(row['Home_Spread']) < 0:
#                 # Double Neg
#                 if row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home')
#                 elif row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 else:
#                     result.append('Push')   
#             else:
#                 # Mine Neg FD Pos
#                 result.append('Home')
#         elif row['Actual_Spread'] > 0:
#             if float(row['Home_Spread']) > 0:
#                 # Double Pos
#                 if row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 elif row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home') 
#                 else:
#                     result.append('Push')
#             else:
#                 # Mine Pos FD Neg
#                 result.append('Away')
#         else:
#             if float(row['Home_Spread']) < 0:
#                 result.append('Away')
#             elif float(row['Home_Spread']) > 0:
#                 result.append('Home')
#             else: 
#                 result.append('Push')
#     e4Missing['Result'] = result
#     e4Missing['Hit'] = e4Missing['bet'] == e4Missing['Result']
#     e4 = pd.concat([e4Present, e4Missing])

#     e5Missing = e5Missing.merge(dailyscores, how='left', left_on=['Away_sportsref', 'Home_sportsref'], right_on=['Away', 'Home'])
#     e5Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e5Missing['Away_Actual'] = e5Missing['Away_Actual'].fillna(e5Missing['Away_Score'])
#     e5Missing['Home_Actual'] = e5Missing['Home_Actual'].fillna(e5Missing['Home_Score'])
#     e5Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)
#     e5Missing = e5Missing.merge(dailyscores, how='left', left_on=['Home_sportsref', 'Away_sportsref'], right_on=['Away', 'Home'])
#     e5Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e5Missing['Away_Actual'] = e5Missing['Away_Actual'].fillna(e5Missing['Home_Score'])
#     e5Missing['Home_Actual'] = e5Missing['Home_Actual'].fillna(e5Missing['Away_Score'])
#     e5Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)

#     e5Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']] = e5Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']].astype(float)
#     e5Missing['Actual_Spread'] = e5Missing['Away_Actual'] - e5Missing['Home_Actual']
#     e5Missing['User_Diff'] = abs(e5Missing['Predicted_Spread'] - e5Missing['Actual_Spread'])
#     e5Missing['FD_Diff'] = abs(e5Missing['Home_Spread'].astype(float) - e5Missing['Actual_Spread'])
#     e5Missing['More_Accurate'] = e5Missing['User_Diff'] < e5Missing['FD_Diff'] 
#     result = [] 
#     for index, row in e5Missing.iterrows():
#         if row['Actual_Spread'] < 0:
#             if float(row['Home_Spread']) < 0:
#                 # Double Neg
#                 if row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home')
#                 elif row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 else:
#                     result.append('Push')   
#             else:
#                 # Mine Neg FD Pos
#                 result.append('Home')
#         elif row['Actual_Spread'] > 0:
#             if float(row['Home_Spread']) > 0:
#                 # Double Pos
#                 if row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 elif row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home') 
#                 else:
#                     result.append('Push')
#             else:
#                 # Mine Pos FD Neg
#                 result.append('Away')
#         else:
#             if float(row['Home_Spread']) < 0:
#                 result.append('Away')
#             elif float(row['Home_Spread']) > 0:
#                 result.append('Home')
#             else: 
#                 result.append('Push')
#     e5Missing['Result'] = result
#     e5Missing['Hit'] = e5Missing['bet'] == e5Missing['Result']
#     e5 = pd.concat([e5Present, e5Missing])

#     e6Missing = e6Missing.merge(dailyscores, how='left', left_on=['Away_sportsref', 'Home_sportsref'], right_on=['Away', 'Home'])
#     e6Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e6Missing['Away_Actual'] = e6Missing['Away_Actual'].fillna(e6Missing['Away_Score'])
#     e6Missing['Home_Actual'] = e6Missing['Home_Actual'].fillna(e6Missing['Home_Score'])
#     e6Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)
#     e6Missing = e6Missing.merge(dailyscores, how='left', left_on=['Home_sportsref', 'Away_sportsref'], right_on=['Away', 'Home'])
#     e6Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e6Missing['Away_Actual'] = e6Missing['Away_Actual'].fillna(e6Missing['Home_Score'])
#     e6Missing['Home_Actual'] = e6Missing['Home_Actual'].fillna(e6Missing['Away_Score'])
#     e6Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)

#     e6Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']] = e6Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']].astype(float)
#     e6Missing['Actual_Spread'] = e6Missing['Away_Actual'] - e6Missing['Home_Actual']
#     e6Missing['User_Diff'] = abs(e6Missing['Predicted_Spread'] - e6Missing['Actual_Spread'])
#     e6Missing['FD_Diff'] = abs(e6Missing['Home_Spread'].astype(float) - e6Missing['Actual_Spread'])
#     e6Missing['More_Accurate'] = e6Missing['User_Diff'] < e6Missing['FD_Diff'] 
#     result = [] 
#     for index, row in e6Missing.iterrows():
#         if row['Actual_Spread'] < 0:
#             if float(row['Home_Spread']) < 0:
#                 # Double Neg
#                 if row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home')
#                 elif row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 else:
#                     result.append('Push')   
#             else:
#                 # Mine Neg FD Pos
#                 result.append('Home')
#         elif row['Actual_Spread'] > 0:
#             if float(row['Home_Spread']) > 0:
#                 # Double Pos
#                 if row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 elif row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home') 
#                 else:
#                     result.append('Push')
#             else:
#                 # Mine Pos FD Neg
#                 result.append('Away')
#         else:
#             if float(row['Home_Spread']) < 0:
#                 result.append('Away')
#             elif float(row['Home_Spread']) > 0:
#                 result.append('Home')
#             else: 
#                 result.append('Push')
#     e6Missing['Result'] = result
#     e6Missing['Hit'] = e6Missing['bet'] == e6Missing['Result']
#     e6 = pd.concat([e6Present, e6Missing])

#     e7Missing = e7Missing.merge(dailyscores, how='left', left_on=['Away_sportsref', 'Home_sportsref'], right_on=['Away', 'Home'])
#     e7Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e7Missing['Away_Actual'] = e7Missing['Away_Actual'].fillna(e7Missing['Away_Score'])
#     e7Missing['Home_Actual'] = e7Missing['Home_Actual'].fillna(e7Missing['Home_Score'])
#     e7Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)
#     e7Missing = e7Missing.merge(dailyscores, how='left', left_on=['Home_sportsref', 'Away_sportsref'], right_on=['Away', 'Home'])
#     e7Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e7Missing['Away_Actual'] = e7Missing['Away_Actual'].fillna(e7Missing['Home_Score'])
#     e7Missing['Home_Actual'] = e7Missing['Home_Actual'].fillna(e7Missing['Away_Score'])
#     e7Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)

#     e7Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']] = e7Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']].astype(float)
#     e7Missing['Actual_Spread'] = e7Missing['Away_Actual'] - e7Missing['Home_Actual']
#     e7Missing['User_Diff'] = abs(e7Missing['Predicted_Spread'] - e7Missing['Actual_Spread'])
#     e7Missing['FD_Diff'] = abs(e7Missing['Home_Spread'].astype(float) - e7Missing['Actual_Spread'])
#     e7Missing['More_Accurate'] = e7Missing['User_Diff'] < e7Missing['FD_Diff'] 
#     result = [] 
#     for index, row in e7Missing.iterrows():
#         if row['Actual_Spread'] < 0:
#             if float(row['Home_Spread']) < 0:
#                 # Double Neg
#                 if row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home')
#                 elif row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 else:
#                     result.append('Push')   
#             else:
#                 # Mine Neg FD Pos
#                 result.append('Home')
#         elif row['Actual_Spread'] > 0:
#             if float(row['Home_Spread']) > 0:
#                 # Double Pos
#                 if row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 elif row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home') 
#                 else:
#                     result.append('Push')
#             else:
#                 # Mine Pos FD Neg
#                 result.append('Away')
#         else:
#             if float(row['Home_Spread']) < 0:
#                 result.append('Away')
#             elif float(row['Home_Spread']) > 0:
#                 result.append('Home')
#             else: 
#                 result.append('Push')
#     e7Missing['Result'] = result
#     e7Missing['Hit'] = e7Missing['bet'] == e7Missing['Result']
#     e7 = pd.concat([e7Present, e7Missing])

#     e8Missing = e8Missing.merge(dailyscores, how='left', left_on=['Away_sportsref', 'Home_sportsref'], right_on=['Away', 'Home'])
#     e8Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e8Missing['Away_Actual'] = e8Missing['Away_Actual'].fillna(e8Missing['Away_Score'])
#     e8Missing['Home_Actual'] = e8Missing['Home_Actual'].fillna(e8Missing['Home_Score'])
#     e8Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)
#     e8Missing = e8Missing.merge(dailyscores, how='left', left_on=['Home_sportsref', 'Away_sportsref'], right_on=['Away', 'Home'])
#     e8Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e8Missing['Away_Actual'] = e8Missing['Away_Actual'].fillna(e8Missing['Home_Score'])
#     e8Missing['Home_Actual'] = e8Missing['Home_Actual'].fillna(e8Missing['Away_Score'])
#     e8Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)

#     e8Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']] = e8Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']].astype(float)
#     e8Missing['Actual_Spread'] = e8Missing['Away_Actual'] - e8Missing['Home_Actual']
#     e8Missing['User_Diff'] = abs(e8Missing['Predicted_Spread'] - e8Missing['Actual_Spread'])
#     e8Missing['FD_Diff'] = abs(e8Missing['Home_Spread'].astype(float) - e8Missing['Actual_Spread'])
#     e8Missing['More_Accurate'] = e8Missing['User_Diff'] < e8Missing['FD_Diff'] 
#     result = [] 
#     for index, row in e8Missing.iterrows():
#         if row['Actual_Spread'] < 0:
#             if float(row['Home_Spread']) < 0:
#                 # Double Neg
#                 if row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home')
#                 elif row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 else:
#                     result.append('Push')   
#             else:
#                 # Mine Neg FD Pos
#                 result.append('Home')
#         elif row['Actual_Spread'] > 0:
#             if float(row['Home_Spread']) > 0:
#                 # Double Pos
#                 if row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 elif row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home') 
#                 else:
#                     result.append('Push')
#             else:
#                 # Mine Pos FD Neg
#                 result.append('Away')
#         else:
#             if float(row['Home_Spread']) < 0:
#                 result.append('Away')
#             elif float(row['Home_Spread']) > 0:
#                 result.append('Home')
#             else: 
#                 result.append('Push')
#     e8Missing['Result'] = result
#     e8Missing['Hit'] = e8Missing['bet'] == e8Missing['Result']
#     e8 = pd.concat([e8Present, e8Missing])

#     e9Missing = e9Missing.merge(dailyscores, how='left', left_on=['Away_sportsref', 'Home_sportsref'], right_on=['Away', 'Home'])
#     e9Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e9Missing['Away_Actual'] = e9Missing['Away_Actual'].fillna(e9Missing['Away_Score'])
#     e9Missing['Home_Actual'] = e9Missing['Home_Actual'].fillna(e9Missing['Home_Score'])
#     e9Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)
#     e9Missing = e9Missing.merge(dailyscores, how='left', left_on=['Home_sportsref', 'Away_sportsref'], right_on=['Away', 'Home'])
#     e9Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e9Missing['Away_Actual'] = e9Missing['Away_Actual'].fillna(e9Missing['Home_Score'])
#     e9Missing['Home_Actual'] = e9Missing['Home_Actual'].fillna(e9Missing['Away_Score'])
#     e9Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)

#     e9Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']] = e9Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']].astype(float)
#     e9Missing['Actual_Spread'] = e9Missing['Away_Actual'] - e9Missing['Home_Actual']
#     e9Missing['User_Diff'] = abs(e9Missing['Predicted_Spread'] - e9Missing['Actual_Spread'])
#     e9Missing['FD_Diff'] = abs(e9Missing['Home_Spread'].astype(float) - e9Missing['Actual_Spread'])
#     e9Missing['More_Accurate'] = e9Missing['User_Diff'] < e9Missing['FD_Diff'] 
#     result = [] 
#     for index, row in e9Missing.iterrows():
#         if row['Actual_Spread'] < 0:
#             if float(row['Home_Spread']) < 0:
#                 # Double Neg
#                 if row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home')
#                 elif row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 else:
#                     result.append('Push')   
#             else:
#                 # Mine Neg FD Pos
#                 result.append('Home')
#         elif row['Actual_Spread'] > 0:
#             if float(row['Home_Spread']) > 0:
#                 # Double Pos
#                 if row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 elif row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home') 
#                 else:
#                     result.append('Push')
#             else:
#                 # Mine Pos FD Neg
#                 result.append('Away')
#         else:
#             if float(row['Home_Spread']) < 0:
#                 result.append('Away')
#             elif float(row['Home_Spread']) > 0:
#                 result.append('Home')
#             else: 
#                 result.append('Push')
#     e9Missing['Result'] = result
#     e9Missing['Hit'] = e9Missing['bet'] == e9Missing['Result']
#     e9 = pd.concat([e9Present, e9Missing])

#     e10Missing = e10Missing.merge(dailyscores, how='left', left_on=['Away_sportsref', 'Home_sportsref'], right_on=['Away', 'Home'])
#     e10Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e10Missing['Away_Actual'] = e10Missing['Away_Actual'].fillna(e10Missing['Away_Score'])
#     e10Missing['Home_Actual'] = e10Missing['Home_Actual'].fillna(e10Missing['Home_Score'])
#     e10Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)
#     e10Missing = e10Missing.merge(dailyscores, how='left', left_on=['Home_sportsref', 'Away_sportsref'], right_on=['Away', 'Home'])
#     e10Missing.rename({'Away_x':'Away', 'Home_x':'Home'}, axis = 1, inplace = True)
#     e10Missing['Away_Actual'] = e10Missing['Away_Actual'].fillna(e10Missing['Home_Score'])
#     e10Missing['Home_Actual'] = e10Missing['Home_Actual'].fillna(e10Missing['Away_Score'])
#     e10Missing.drop(['Away_y', 'Away_Score', 'Home_y', 'Home_Score', 'M'], axis = 1, inplace=True)

#     e10Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']] = e10Missing[['Actual_Spread', 'Home_Actual', 'Away_Actual']].astype(float)
#     e10Missing['Actual_Spread'] = e10Missing['Away_Actual'] - e10Missing['Home_Actual']
#     e10Missing['User_Diff'] = abs(e10Missing['Predicted_Spread'] - e10Missing['Actual_Spread'])
#     e10Missing['FD_Diff'] = abs(e10Missing['Home_Spread'].astype(float) - e10Missing['Actual_Spread'])
#     e10Missing['More_Accurate'] = e10Missing['User_Diff'] < e10Missing['FD_Diff'] 
#     result = [] 
#     for index, row in e10Missing.iterrows():
#         if row['Actual_Spread'] < 0:
#             if float(row['Home_Spread']) < 0:
#                 # Double Neg
#                 if row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home')
#                 elif row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 else:
#                     result.append('Push')   
#             else:
#                 # Mine Neg FD Pos
#                 result.append('Home')
#         elif row['Actual_Spread'] > 0:
#             if float(row['Home_Spread']) > 0:
#                 # Double Pos
#                 if row['Actual_Spread'] > float(row['Home_Spread']):
#                     result.append('Away')
#                 elif row['Actual_Spread'] < float(row['Home_Spread']):
#                     result.append('Home') 
#                 else:
#                     result.append('Push')
#             else:
#                 # Mine Pos FD Neg
#                 result.append('Away')
#         else:
#             if float(row['Home_Spread']) < 0:
#                 result.append('Away')
#             elif float(row['Home_Spread']) > 0:
#                 result.append('Home')
#             else: 
#                 result.append('Push')
#     e10Missing['Result'] = result
#     e10Missing['Hit'] = e10Missing['bet'] == e10Missing['Result']
#     e10 = pd.concat([e10Present, e10Missing])

# #Scrape and prep Torvik Data
# url = requests.get('https://www.barttorvik.com/#')
# parse = BeautifulSoup(url.text, "lxml").prettify()
# start = parse.find("<table")
# end = parse.find("</table")
# tor = pd.read_html(parse[start:end+8])[0]
# tor.columns = tor.columns.droplevel()
# tor['AdjOE'] = tor['AdjOE'].str.split(' ').str[0]
# tor['AdjDE'] = tor['AdjDE'].str.split(' ').str[0]
# tor['Barthag'] = tor['Barthag'].str.split(' ').str[0]
# tor['EFG%'] = tor['EFG%'].str.split(' ').str[0]
# tor['EFGD%'] = tor['EFGD%'].str.split(' ').str[0]
# tor['TOR'] = tor['TOR'].str.split(' ').str[0]
# tor['TORD'] = tor['TORD'].str.split(' ').str[0]
# tor['ORB'] = tor['ORB'].str.split(' ').str[0]
# tor['DRB'] = tor['DRB'].str.split(' ').str[0]
# tor['FTR'] = tor['FTR'].str.split(' ').str[0]
# tor['FTRD'] = tor['FTRD'].str.split(' ').str[0]
# tor['2P%'] = tor['2P%'].str.split(' ').str[0]
# tor['2P%D'] = tor['2P%D'].str.split(' ').str[0]
# tor['3P%'] = tor['3P%'].str.split(' ').str[0]
# tor['3P%D'] = tor['3P%D'].str.split(' ').str[0]
# tor['3PR'] = tor['3PR'].str.split(' ').str[0]
# tor['3PRD'] = tor['3PRD'].str.split(' ').str[0]
# tor['Adj T.'] = tor['Adj T.'].str.split(' ').str[0]
# tor['WAB'] = tor['WAB'].str.split(' ').str[0]
# tor['Team'] = tor['Team'].apply(lambda x: (x.split('  (H)')[0]) if '(H)' in x else x)
# tor['Team'] = tor['Team'].apply(lambda x: (x.split('  (A)')[0]) if '(A)' in x else x)
# tor.to_csv('torvik.csv')

# #Scrape and prep offense Data
# s = 'https://basketball.realgm.com/ncaa/team_stats/%s/Averages/Team_Totals/0' % YEAR
# url = requests.get(s)
# parse = BeautifulSoup(url.text, "lxml").prettify()
# start = parse.find("<table")
# end = parse.find("</table")
# off = pd.read_html(parse[start:end+8])[0]
# off.drop(['#'], axis = 1, inplace = True)
# off
# off.to_csv('off.csv')

# #Scrape and prep defense Data
# s = 'https://basketball.realgm.com/ncaa/team-stats/%s/Averages/Opponent_Totals/0' % YEAR
# url = requests.get(s)
# parse = BeautifulSoup(url.text, "lxml").prettify()
# start = parse.find("<table")
# end = parse.find("</table")
# opp = pd.read_html(parse[start:end+8])[0]
# opp.drop(['#'], axis = 1, inplace = True)
# opp
# opp.to_csv('opp.csv')

# #Scrape and prep Line data using Selenium
# driver = webdriver.Firefox()
# driver.get("https://www.sportsline.com/college-basketball/odds/")
# wait = WebDriverWait(driver, 1)
# driver.find_element("xpath", '/html/body/div[3]/div/div/div/button').click()

# while True:
#     if driver.find_element("xpath", '/html/body/div[1]/div[5]/div/section[1]/div/main/div/div[2]/section/div[3]/div[2]/button').is_enabled():
#         driver.execute_script("arguments[0].click();", driver.find_element("xpath", '/html/body/div[1]/div[5]/div/section[1]/div/main/div/div[2]/section/div[3]/div[2]/button'))
#     else:
#         break

# html = driver.page_source
# driver.close()
# parse = BeautifulSoup(html, 'lxml').prettify()
# start = parse.find("<table")
# end = parse.find("</table")
# line = pd.read_html(parse[start:end+8])[0]
# line = line[line['Matchup'] != line['consensus']]
# line.drop('Proj Score', axis = 1, inplace=True)
# line.dropna(inplace=True)
# line.rename({'Unnamed: 3' : 'betmgm'}, axis = 1, inplace=True)
# line['line'] = line['Matchup'].str.rsplit(' ', n = 1)
# line['Record'] = line['line'].apply(lambda x: x[-1]) 
# line['Team'] = line['line'].apply(lambda x: x[0]) 
# line.drop(['line', 'Matchup'], axis = 1, inplace=True)
# col = line.pop("Record")
# line.insert(0, "Record", col)
# col = line.pop("Team")
# line.insert(0, "Team", col)
# line['Team'] = line['Team'].astype(str)
# line['Team'] = line['Team'].str[:-1]
# line.reset_index(inplace=True)
# line.drop('index', axis = 1, inplace=True)

# #Join the line on itself to get home vs away matchups, then prep it
# line = line[['Team', 'Record', 'fanduel']].astype(str)
# away = line.iloc[::2].reset_index()
# away.rename({'Team':'Away', 'Record':'Away_Record', 'fanduel':'Away_fanduel'}, axis=1, inplace=True)
# away.drop(['index'], axis=1, inplace=True)
# away = away[away['Away_fanduel'] != '--']
# away['Away_Spread'] = away['Away_fanduel'].apply(lambda x: (x.split(' ')[0]))
# away['Away_odds'] = away['Away_fanduel'].apply(lambda x: (x.split(' ')[2]))
# home = line.iloc[1: , :].iloc[::2].reset_index()
# home.rename({'Team':'Home', 'Record':'Home_Record', 'fanduel':'Home_fanduel'}, axis=1, inplace=True)
# line = pd.concat([away, home], axis=1)
# line.drop(['index'], axis=1, inplace=True)
# line = line[line['Home_fanduel'] != '--']
# line['Home_Spread'] = line['Home_fanduel'].apply(lambda x: (x.split(' ')[0]))
# line['Home_odds'] = line['Home_fanduel'].apply(lambda x: (x.split(' ')[2]))
# line.drop(['Home_fanduel', 'Away_fanduel'], axis = 1, inplace=True)
# line = x.merge(line, how='right', left_on='line', right_on='Away')
# line.rename({'team':'Away_team', 'abr':'Away_abr', 'line':'Away_line', 'tor':'Away_tor', 'hca':'Away_hca', 'sportsref':'Away_sportsref', 'sos':'Away_sos'}, axis=1, inplace=True)
# col = line.pop("Away_team")
# line.insert(6, "Away_team", col)
# col = line.pop("Away_abr")
# line.insert(6, "Away_abr", col)
# col = line.pop("Away_line")
# line.insert(6, "Away_line", col)
# col = line.pop("Away_tor")
# line.insert(6, "Away_tor", col)
# col = line.pop("Away_hca")
# line.insert(6, "Away_hca", col)
# col = line.pop("Away_sportsref")
# line.insert(6, "Away_sportsref", col)
# col = line.pop("Away_sos")
# line.insert(6, "Away_sos", col)
# line = x.merge(line, how='right', left_on='line', right_on='Home')
# line.rename({'team':'Home_team', 'abr':'Home_abr', 'line':'Home_line', 'tor':'Home_tor', 'hca':'Home_hca', 'sportsref':'Home_sportsref', 'sos':'Home_sos'}, axis=1, inplace=True)
# col = line.pop("Home_team")
# line.insert(16, "Home_team", col)
# col = line.pop("Home_abr")
# line.insert(16, "Home_abr", col)
# col = line.pop("Home_line")
# line.insert(16, "Home_line", col)
# col = line.pop("Home_tor")
# line.insert(16, "Home_tor", col)
# col = line.pop("Home_hca")
# line.insert(16, "Home_hca", col)
# col = line.pop("Home_sportsref")
# line.insert(16, "Home_sportsref", col)
# col = line.pop("Home_sos")
# line.insert(16, "Home_sos", col)
# line = line[(line['Home_team'] == line['Home_team']) & (line['Away_team'] == line['Away_team'])]
# line.to_csv('line.csv')
# line

# #Open offense stats and merge with abbreviations
# x = x.sort_values('team').reset_index()
# off = pd.read_csv('off.csv')
# off = off.merge(x, how='left', left_on='Team', right_on='team')
# off.drop(['Unnamed: 0', 'team'], axis = 1, inplace=True)
# off.insert(1, 'abr', off.pop('abr'))
# off.insert(2, 'line', off.pop('line'))
# off.insert(3, 'tor', off.pop('tor'))
# off.sort_values(by='Team', ascending=True, inplace=True)

# #Open defense stats and merge with abbreviations
# opp = pd.read_csv('opp.csv')
# opp.drop('Unnamed: 0', axis = 1, inplace=True)
# opp = opp.sort_values(by='Team', ascending=True).reset_index()
# stats = off.merge(opp, how='left', on='Team')
# stats = stats.sort_values('Team').reset_index()
# stats[['Team', 'abr', 'line', 'tor', 'sportsref', 'sos']] = x[['team', 'abr', 'line', 'tor', 'sportsref', 'sos']]

# #Open torvik stats and merge with abbreviations
# torvik = pd.read_csv('torvik.csv')
# torvik.drop('Unnamed: 0', axis = 1, inplace=True)
# torvik['Team'] = torvik['Team'].apply(lambda x: (x.split(' vs.')[0][:-1] if ' vs.' in x else x))
# stats = stats.merge(torvik, how='left', left_on='tor', right_on='Team')
# stats.drop('Team_y', axis = 1, inplace=True)
# stats.rename({'Team_x':'team'}, axis=1, inplace=True)

# #ste numerical columns to floats
# stats[['Rk', 'G', 'AdjOE', 'AdjDE', 'Barthag', 'EFG%', 'EFGD%', 'TOR',
#        'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P%', '2P%D', '3P%', '3P%D',
#        '3PR', '3PRD', 'Adj T.', 'WAB']] = stats[[
#        'Rk', 'G', 'AdjOE', 'AdjDE', 'Barthag', 'EFG%', 'EFGD%', 'TOR',
#        'TORD', 'ORB', 'DRB', 'FTR', 'FTRD', '2P%', '2P%D', '3P%', '3P%D',
#        '3PR', '3PRD', 'Adj T.', 'WAB']].astype(float)

# #Add Homecourt Advantage
# HCA = pd.read_csv('HCA.csv')
# stats = stats.merge(HCA, how='left', left_on='hca', right_on='Team')
# stats['HC_ADV'] = stats['HC_ADV'].fillna(3.2).astype(float)

# #Add Strength of Schedule
# SOS = pd.read_csv('sos.csv')
# SOS.drop('Unnamed: 0', axis = 1, inplace = True)
# stats = stats.merge(SOS, how='left', left_on='sos', right_on='SOSTeam')
# stats.to_csv('stats.csv')

# ##################### EQUATION 1 #####################
# away_score = []
# home_score = []
# away_conf = []
# home_conf = []

# for index, row in line.iterrows():
#     a = stats[stats['line'] == row['Away']]
#     # print("Away: " + row['Away'])
#     h = stats[stats['line'] == row['Home']]
#     # print("Home: " + row['Home'])
#     h_pos = POS * (1 - ((((h.iloc[0]['TOR'] + a.iloc[0]['TORD']) / 2) - ((a.iloc[0]['TOR'] + h.iloc[0]['TORD']) / 2)) / 100)) * (1 - ((((a.iloc[0]['ORB'] + h.iloc[0]['DRB']) / 2) - ((h.iloc[0]['ORB'] + a.iloc[0]['DRB']) / 2)) / 100)) + ((((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100) + (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#     a_pos = POS * (1 - ((((a.iloc[0]['TOR'] + h.iloc[0]['TORD']) / 2) - ((h.iloc[0]['TOR'] + a.iloc[0]['TORD']) / 2)) / 100)) * (1 - ((((h.iloc[0]['ORB'] + a.iloc[0]['DRB']) / 2) - ((a.iloc[0]['ORB'] + h.iloc[0]['DRB']) / 2)) / 100)) + ((((a.iloc[0]['3P%'] + h.iloc[0]['3P%D']) / 2) / 100) + (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#     home = ((((h.iloc[0]['AdjOE'] + a.iloc[0]['AdjDE']) / 2) * h_pos) / 100) - ((h.iloc[0]['Rk'] - a.iloc[0]['Rk']) / 25)
#     away = ((((a.iloc[0]['AdjOE'] + h.iloc[0]['AdjDE']) / 2) * a_pos) / 100) - ((a.iloc[0]['Rk'] - h.iloc[0]['Rk']) / 25)
#     home += ((((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100) + (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#     away += ((((a.iloc[0]['3P%'] + h.iloc[0]['3P%D']) / 2) / 100) + (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#     away_score.append(round(away, 2))
#     home_score.append(round(home, 2))
#     away_conf.append(a.iloc[0]['Conf'])
#     home_conf.append(h.iloc[0]['Conf'])
#     # print('Score: ' + a.iloc[0]['team'] + ' ' + str(round(away, 2)) + ' @ ' + h.iloc[0]['team'] + ' ' +  str(round(home, 2)) + ' TOTAL: ' + str(round(home + away, 2)))

# line['Predicted_Away_Score'] = away_score
# line['Predicted_Home_Score'] = home_score
# line.insert(7, 'Away_Conf', away_conf)
# line.insert(17, 'Home_Conf', home_conf)
# line['Predicted_Spread'] = -(line['Predicted_Home_Score'] - line['Predicted_Away_Score'])

# bet = []
# bet_by = []
# for index, row in line.iterrows():
#     bet_by.append(abs(float(row['Home_Spread']) - float(row['Predicted_Spread'])))
#     if row['Predicted_Spread'] < 0:
#         if float(row['Home_Spread']) < 0:
#             # Double Neg
#             if row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home')
#             elif row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             else:
#                 bet.append('Push')   
#         else:
#             # Mine Neg FD Pos
#             bet.append('Home')
#     elif row['Predicted_Spread'] > 0:
#         if float(row['Home_Spread']) > 0:
#             # Double Pos
#             if row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             elif row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home') 
#             else:
#                 bet.append('Push')
#         else:
#             # Mine Pos FD Neg
#             bet.append('Away')
#     else:
#         if float(row['Home_Spread']) < 0:
#            bet.append('Away')
#         elif float(row['Home_Spread']) > 0:
#            bet.append('Home')
#         else: 
#            bet.append('Push')
           

# line['bet'] = bet
# line['bet_by'] = bet_by
# line.insert(0, 'date', date.today())
# line[['Away_Actual', 'Home_Actual', 'Actual_Spread', 'User_Diff', 'FD_Diff']] = np.nan
# line['date'] = date.today()

# e1['date'] = e1.apply(lambda x: (x['date'] + timedelta(days = 1)) if x['Away_Actual']!=x['Away_Actual'] else x['date'], axis = 1)
# e1['date'] = e1.apply(lambda x: date.today() if ((x['Away_Actual']!=x['Away_Actual'])  & (x['date'] > date.today())) else x['date'], axis = 1)
# e1 = pd.concat([e1, line])
# e1.drop_duplicates(subset=['date', 'Away', 'Home'], keep = 'last', inplace=True)
# # e1.drop(['Unnamed: 0.1_x', 'Unnamed: 0.1_y'], axis = 1, inplace = True)



# ##################### EQUATION 2 #####################
# away_score = []
# home_score = []

# for index, row in line.iterrows():
#     a = stats[stats['line'] == row['Away']]
#     h = stats[stats['line'] == row['Home']]
#     h_pos = POS * (1 - ((((h.iloc[0]['TOR'] + a.iloc[0]['TORD']) / 2) - ((a.iloc[0]['TOR'] + h.iloc[0]['TORD']) / 2)) / 100)) * (1 - ((((a.iloc[0]['ORB'] + h.iloc[0]['DRB']) / 2) - ((h.iloc[0]['ORB'] + a.iloc[0]['DRB']) / 2)) / 100)) + ((((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100) + (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#     a_pos = POS * (1 - ((((a.iloc[0]['TOR'] + h.iloc[0]['TORD']) / 2) - ((h.iloc[0]['TOR'] + a.iloc[0]['TORD']) / 2)) / 100)) * (1 - ((((h.iloc[0]['ORB'] + a.iloc[0]['DRB']) / 2) - ((a.iloc[0]['ORB'] + h.iloc[0]['DRB']) / 2)) / 100)) + ((((a.iloc[0]['3P%'] + h.iloc[0]['3P%D']) / 2) / 100) + (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#     home = ((((h.iloc[0]['AdjOE'] + a.iloc[0]['AdjDE']) / 2) * h_pos) / 100) - ((h.iloc[0]['Rk'] - a.iloc[0]['Rk']) / 25)
#     away = ((((a.iloc[0]['AdjOE'] + h.iloc[0]['AdjDE']) / 2) * a_pos) / 100) - ((a.iloc[0]['Rk'] - h.iloc[0]['Rk']) / 25)
#     away_score.append(round(away, 2))
#     home_score.append(round(home, 2))
    
# line['Predicted_Away_Score'] = away_score
# line['Predicted_Home_Score'] = home_score
# line['Predicted_Spread'] = -(line['Predicted_Home_Score'] - line['Predicted_Away_Score'])

# bet = []
# bet_by = []
# for index, row in line.iterrows():
#     bet_by.append(abs(float(row['Home_Spread']) - float(row['Predicted_Spread'])))
#     if row['Predicted_Spread'] < 0:
#         if float(row['Home_Spread']) < 0:
#             # Double Neg
#             if row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home')
#             elif row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             else:
#                 bet.append('Push')   
#         else:
#             # Mine Neg FD Pos
#             bet.append('Home')
#     elif row['Predicted_Spread'] > 0:
#         if float(row['Home_Spread']) > 0:
#             # Double Pos
#             if row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             elif row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home') 
#             else:
#                 bet.append('Push')
#         else:
#             # Mine Pos FD Neg
#             bet.append('Away')
#     else:
#         if float(row['Home_Spread']) < 0:
#            bet.append('Away')
#         elif float(row['Home_Spread']) > 0:
#            bet.append('Home')
#         else: 
#            bet.append('Push')
           


# line['bet'] = bet
# line['bet_by'] = bet_by
# line[['Away_Actual', 'Home_Actual', 'Actual_Spread', 'User_Diff', 'FD_Diff']] = np.nan
# line['date'] = date.today()

# e2['date'] = e2.apply(lambda x: (x['date'] + timedelta(days = 1)) if x['Away_Actual']!=x['Away_Actual'] else x['date'], axis = 1)
# e2['date'] = e2.apply(lambda x: date.today() if ((x['Away_Actual']!=x['Away_Actual'])  & (x['date'] > date.today())) else x['date'], axis = 1)
# e2 = pd.concat([e2, line])
# e2.drop_duplicates(subset=['date', 'Away', 'Home'], keep = 'last', inplace=True)
# # e2.drop(['Unnamed: 0.1_x', 'Unnamed: 0.1_y'], axis = 1, inplace = True)




# ##################### EQUATION 3 #####################
# away_score = []
# home_score = []

# for index, row in line.iterrows():
#     a = stats[stats['line'] == row['Away']]
#     h = stats[stats['line'] == row['Home']]
#     h_pos = POS * (1 - ((((h.iloc[0]['TOR'] + a.iloc[0]['TORD']) / 2) - ((a.iloc[0]['TOR'] + h.iloc[0]['TORD']) / 2)) / 100)) * (1 - ((((a.iloc[0]['ORB'] + h.iloc[0]['DRB']) / 2) - ((h.iloc[0]['ORB'] + a.iloc[0]['DRB']) / 2)) / 100)) + ((((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100) + (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#     a_pos = POS * (1 - ((((a.iloc[0]['TOR'] + h.iloc[0]['TORD']) / 2) - ((h.iloc[0]['TOR'] + a.iloc[0]['TORD']) / 2)) / 100)) * (1 - ((((h.iloc[0]['ORB'] + a.iloc[0]['DRB']) / 2) - ((a.iloc[0]['ORB'] + h.iloc[0]['DRB']) / 2)) / 100)) + ((((a.iloc[0]['3P%'] + h.iloc[0]['3P%D']) / 2) / 100) + (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#     home = (h_pos *  3 * (((((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100) * (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100)))) + (h_pos *  1 * (((((h.iloc[0]['FTR'] + a.iloc[0]['FTRD']) / 2) / 100)))) + (h_pos * 2 * ((((h.iloc[0]['2P%'] + a.iloc[0]['2P%D']) / 2) / 100)) * (1 - ((((h.iloc[0]['FTR'] + a.iloc[0]['FTRD']) / (2 * 2)) / 100)) - ((((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100)))) - ((h.iloc[0]['Rk'] - a.iloc[0]['Rk']) / 25) + h.iloc[0]['HC_ADV']
#     away = (a_pos *  3 * (((((a.iloc[0]['3P%'] + h.iloc[0]['3P%D']) / 2) / 100) * (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100)))) + (a_pos *  1 * (((((a.iloc[0]['FTR'] + h.iloc[0]['FTRD']) / 2) / 100)))) + (a_pos * 2 * ((((a.iloc[0]['2P%'] + h.iloc[0]['2P%D']) / 2) / 100)) * (1 - ((((a.iloc[0]['FTR'] + h.iloc[0]['FTRD']) / (2 * 2)) / 100)) - ((((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100)))) - ((a.iloc[0]['Rk'] - h.iloc[0]['Rk']) / 25)
#     away_score.append(round(away, 2))
#     home_score.append(round(home, 2))
    
# line['Predicted_Away_Score'] = away_score
# line['Predicted_Home_Score'] = home_score
# line['Predicted_Spread'] = -(line['Predicted_Home_Score'] - line['Predicted_Away_Score'])

# bet = []
# bet_by = []
# for index, row in line.iterrows():
#     bet_by.append(abs(float(row['Home_Spread']) - float(row['Predicted_Spread'])))
#     if row['Predicted_Spread'] < 0:
#         if float(row['Home_Spread']) < 0:
#             # Double Neg
#             if row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home')
#             elif row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             else:
#                 bet.append('Push')   
#         else:
#             # Mine Neg FD Pos
#             bet.append('Home')
#     elif row['Predicted_Spread'] > 0:
#         if float(row['Home_Spread']) > 0:
#             # Double Pos
#             if row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             elif row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home') 
#             else:
#                 bet.append('Push')
#         else:
#             # Mine Pos FD Neg
#             bet.append('Away')
#     else:
#         if float(row['Home_Spread']) < 0:
#            bet.append('Away')
#         elif float(row['Home_Spread']) > 0:
#            bet.append('Home')
#         else: 
#            bet.append('Push')
           


# line['bet'] = bet
# line['bet_by'] = bet_by
# line[['Away_Actual', 'Home_Actual', 'Actual_Spread', 'User_Diff', 'FD_Diff']] = np.nan
# line['date'] = date.today()

# e3['date'] = e3.apply(lambda x: (x['date'] + timedelta(days = 1)) if x['Away_Actual']!=x['Away_Actual'] else x['date'], axis = 1)
# e3['date'] = e3.apply(lambda x: date.today() if ((x['Away_Actual']!=x['Away_Actual'])  & (x['date'] > date.today())) else x['date'], axis = 1)
# e3 = pd.concat([e3, line])
# e3.drop_duplicates(subset=['date', 'Away', 'Home'], keep = 'last', inplace=True)
# # e3.drop(['Unnamed: 0.1_x', 'Unnamed: 0.1_y'], axis = 1, inplace = True)



# ##################### EQUATION 4 #####################
# away_score = []
# home_score = []

# for index, row in line.iterrows():
#     a = stats[stats['line'] == row['Away']]
#     h = stats[stats['line'] == row['Home']]
#     home = ((((h.iloc[0]['AdjOE'] + a.iloc[0]['AdjDE']) / 2) * POS) / 100) + h.iloc[0]['HC_ADV']
#     away = ((((a.iloc[0]['AdjOE'] + h.iloc[0]['AdjDE']) / 2) * POS) / 100)
#     away_score.append(round(away, 2))
#     home_score.append(round(home, 2))
    
# line['Predicted_Away_Score'] = away_score
# line['Predicted_Home_Score'] = home_score
# line['Predicted_Spread'] = -(line['Predicted_Home_Score'] - line['Predicted_Away_Score'])

# bet = []
# bet_by = []
# for index, row in line.iterrows():
#     bet_by.append(abs(float(row['Home_Spread']) - float(row['Predicted_Spread'])))
#     if row['Predicted_Spread'] < 0:
#         if float(row['Home_Spread']) < 0:
#             # Double Neg
#             if row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home')
#             elif row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             else:
#                 bet.append('Push')   
#         else:
#             # Mine Neg FD Pos
#             bet.append('Home')
#     elif row['Predicted_Spread'] > 0:
#         if float(row['Home_Spread']) > 0:
#             # Double Pos
#             if row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             elif row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home') 
#             else:
#                 bet.append('Push')
#         else:
#             # Mine Pos FD Neg
#             bet.append('Away')
#     else:
#         if float(row['Home_Spread']) < 0:
#            bet.append('Away')
#         elif float(row['Home_Spread']) > 0:
#            bet.append('Home')
#         else: 
#            bet.append('Push')
           


# line['bet'] = bet
# line['bet_by'] = bet_by
# line[['Away_Actual', 'Home_Actual', 'Actual_Spread', 'User_Diff', 'FD_Diff']] = np.nan
# line['date'] = date.today()

# e4['date'] = e4.apply(lambda x: (x['date'] + timedelta(days = 1)) if x['Away_Actual']!=x['Away_Actual'] else x['date'], axis = 1)
# e4['date'] = e4.apply(lambda x: date.today() if ((x['Away_Actual']!=x['Away_Actual'])  & (x['date'] > date.today())) else x['date'], axis = 1)
# e4 = pd.concat([e4, line])
# e4.drop_duplicates(subset=['date', 'Away', 'Home'], keep = 'last', inplace=True)


# ##################### EQUATION 5 #####################
# away_score = []
# home_score = []

# for index, row in line.iterrows():
#     a = stats[stats['line'] == row['Away']]
#     h = stats[stats['line'] == row['Home']]
#     home =  (((((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) * (((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100)) * (SHOT_POS * 3)) + ((((h.iloc[0]['FTR'] + a.iloc[0]['FTRD']) / (2)) / 100) * (h.iloc[0]['FT%_x']) * (SHOT_POS * 1)) + ((1 - (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) + (((h.iloc[0]['FTR'] + a.iloc[0]['FTRD']) / (2*2)) / 100)) * (((h.iloc[0]['2P%'] + a.iloc[0]['2P%D']) / 2) / 100) * (SHOT_POS * 2))
#     away = (((((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) * (((a.iloc[0]['3P%'] + h.iloc[0]['3P%D']) / 2) / 100)) * (SHOT_POS * 3)) + ((((a.iloc[0]['FTR'] + h.iloc[0]['FTRD']) / (2)) / 100) * (a.iloc[0]['FT%_x']) * (SHOT_POS * 1)) + ((1 - (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) + (((a.iloc[0]['FTR'] + h.iloc[0]['FTRD']) / (2*2)) / 100)) * (((a.iloc[0]['2P%'] + h.iloc[0]['2P%D']) / 2) / 100) * (SHOT_POS * 2))
#     away_score.append(round(away, 2))
#     home_score.append(round(home, 2))
    
# line['Predicted_Away_Score'] = away_score
# line['Predicted_Home_Score'] = home_score
# line['Predicted_Spread'] = -(line['Predicted_Home_Score'] - line['Predicted_Away_Score'])

# bet = []
# bet_by = []
# for index, row in line.iterrows():
#     bet_by.append(abs(float(row['Home_Spread']) - float(row['Predicted_Spread'])))
#     if row['Predicted_Spread'] < 0:
#         if float(row['Home_Spread']) < 0:
#             # Double Neg
#             if row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home')
#             elif row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             else:
#                 bet.append('Push')   
#         else:
#             # Mine Neg FD Pos
#             bet.append('Home')
#     elif row['Predicted_Spread'] > 0:
#         if float(row['Home_Spread']) > 0:
#             # Double Pos
#             if row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             elif row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home') 
#             else:
#                 bet.append('Push')
#         else:
#             # Mine Pos FD Neg
#             bet.append('Away')
#     else:
#         if float(row['Home_Spread']) < 0:
#            bet.append('Away')
#         elif float(row['Home_Spread']) > 0:
#            bet.append('Home')
#         else: 
#            bet.append('Push')
           


# line['bet'] = bet
# line['bet_by'] = bet_by
# line[['Away_Actual', 'Home_Actual', 'Actual_Spread', 'User_Diff', 'FD_Diff']] = np.nan
# line['date'] = date.today()

# e5['date'] = e5.apply(lambda x: (x['date'] + timedelta(days = 1)) if x['Away_Actual']!=x['Away_Actual'] else x['date'], axis = 1)
# e5['date'] = e5.apply(lambda x: date.today() if ((x['Away_Actual']!=x['Away_Actual'])  & (x['date'] > date.today())) else x['date'], axis = 1)
# e5 = pd.concat([e5, line])
# e5.drop_duplicates(subset=['date', 'Away', 'Home'], keep = 'last', inplace=True)


# ##################### EQUATION 6 #####################
# away_score = []
# home_score = []

# for index, row in line.iterrows():
#     a = stats[stats['line'] == row['Away']]
#     h = stats[stats['line'] == row['Home']]
#     home =  (((((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) * (((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100)) * (SHOT_POS * 3)) + ((((h.iloc[0]['FTR'] + a.iloc[0]['FTRD']) / (2)) / 100) * (h.iloc[0]['FT%_x']) * (SHOT_POS * 1)) + ((1 - (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) + (((h.iloc[0]['FTR'] + a.iloc[0]['FTRD']) / (2*2)) / 100)) * (((h.iloc[0]['2P%'] + a.iloc[0]['2P%D']) / 2) / 100) * (SHOT_POS * 2)) + h.iloc[0]['HC_ADV'] + h.iloc[0]['SOS']
#     away = (((((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) * (((a.iloc[0]['3P%'] + h.iloc[0]['3P%D']) / 2) / 100)) * (SHOT_POS * 3)) + ((((a.iloc[0]['FTR'] + h.iloc[0]['FTRD']) / (2)) / 100) * (a.iloc[0]['FT%_x']) * (SHOT_POS * 1)) + ((1 - (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) + (((a.iloc[0]['FTR'] + h.iloc[0]['FTRD']) / (2*2)) / 100)) * (((a.iloc[0]['2P%'] + h.iloc[0]['2P%D']) / 2) / 100) * (SHOT_POS * 2)) + a.iloc[0]['SOS']
#     away_score.append(round(away, 2))
#     home_score.append(round(home, 2))
    
# line['Predicted_Away_Score'] = away_score
# line['Predicted_Home_Score'] = home_score
# line['Predicted_Spread'] = -(line['Predicted_Home_Score'] - line['Predicted_Away_Score'])

# bet = []
# bet_by = []
# for index, row in line.iterrows():
#     bet_by.append(abs(float(row['Home_Spread']) - float(row['Predicted_Spread'])))
#     if row['Predicted_Spread'] < 0:
#         if float(row['Home_Spread']) < 0:
#             # Double Neg
#             if row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home')
#             elif row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             else:
#                 bet.append('Push')   
#         else:
#             # Mine Neg FD Pos
#             bet.append('Home')
#     elif row['Predicted_Spread'] > 0:
#         if float(row['Home_Spread']) > 0:
#             # Double Pos
#             if row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             elif row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home') 
#             else:
#                 bet.append('Push')
#         else:
#             # Mine Pos FD Neg
#             bet.append('Away')
#     else:
#         if float(row['Home_Spread']) < 0:
#            bet.append('Away')
#         elif float(row['Home_Spread']) > 0:
#            bet.append('Home')
#         else: 
#            bet.append('Push')
           


# line['bet'] = bet
# line['bet_by'] = bet_by
# line[['Away_Actual', 'Home_Actual', 'Actual_Spread', 'User_Diff', 'FD_Diff']] = np.nan
# line['date'] = date.today()

# e6['date'] = e6.apply(lambda x: (x['date'] + timedelta(days = 1)) if x['Away_Actual']!=x['Away_Actual'] else x['date'], axis = 1)
# e6['date'] = e6.apply(lambda x: date.today() if ((x['Away_Actual']!=x['Away_Actual'])  & (x['date'] > date.today())) else x['date'], axis = 1)
# e6 = pd.concat([e6, line])
# e6.drop_duplicates(subset=['date', 'Away', 'Home'], keep = 'last', inplace=True)


# ##################### EQUATION 7 #####################
# away_score = []
# home_score = []

# for index, row in line.iterrows():
#     a = stats[stats['line'] == row['Away']]
#     h = stats[stats['line'] == row['Home']]
#     if abs(float(row['Home_Spread'])) <= 5:
#         home =  (((((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) * (((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100)) * (SHOT_POS * 3)) + ((((h.iloc[0]['FTR'] + a.iloc[0]['FTRD']) / (2)) / 100) * (h.iloc[0]['FT%_x']) * (SHOT_POS * 1)) + ((1 - (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) + (((h.iloc[0]['FTR'] + a.iloc[0]['FTRD']) / (2*2)) / 100)) * (((h.iloc[0]['2P%'] + a.iloc[0]['2P%D']) / 2) / 100) * (SHOT_POS * 2)) + h.iloc[0]['HC_ADV'] + h.iloc[0]['SOS']
#         away = (((((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) * (((a.iloc[0]['3P%'] + h.iloc[0]['3P%D']) / 2) / 100)) * (SHOT_POS * 3)) + ((((a.iloc[0]['FTR'] + h.iloc[0]['FTRD']) / (2)) / 100) * (a.iloc[0]['FT%_x']) * (SHOT_POS * 1)) + ((1 - (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) + (((a.iloc[0]['FTR'] + h.iloc[0]['FTRD']) / (2*2)) / 100)) * (((a.iloc[0]['2P%'] + h.iloc[0]['2P%D']) / 2) / 100) * (SHOT_POS * 2)) + a.iloc[0]['SOS']
#     elif (abs(float(row['Home_Spread'])) > 5) & (abs(float(row['Home_Spread'])) <= 10):
#         home = ((((h.iloc[0]['AdjOE'] + a.iloc[0]['AdjDE']) / 2) * POS) / 100) + h.iloc[0]['HC_ADV']
#         away = ((((a.iloc[0]['AdjOE'] + h.iloc[0]['AdjDE']) / 2) * POS) / 100)
#     else:
#         h_pos = POS * (1 - ((((h.iloc[0]['TOR'] + a.iloc[0]['TORD']) / 2) - ((a.iloc[0]['TOR'] + h.iloc[0]['TORD']) / 2)) / 100)) * (1 - ((((a.iloc[0]['ORB'] + h.iloc[0]['DRB']) / 2) - ((h.iloc[0]['ORB'] + a.iloc[0]['DRB']) / 2)) / 100)) + ((((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100) + (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#         a_pos = POS * (1 - ((((a.iloc[0]['TOR'] + h.iloc[0]['TORD']) / 2) - ((h.iloc[0]['TOR'] + a.iloc[0]['TORD']) / 2)) / 100)) * (1 - ((((h.iloc[0]['ORB'] + a.iloc[0]['DRB']) / 2) - ((a.iloc[0]['ORB'] + h.iloc[0]['DRB']) / 2)) / 100)) + ((((a.iloc[0]['3P%'] + h.iloc[0]['3P%D']) / 2) / 100) + (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#         home = ((((h.iloc[0]['AdjOE'] + a.iloc[0]['AdjDE']) / 2) * h_pos) / 100) - ((h.iloc[0]['Rk'] - a.iloc[0]['Rk']) / 25)
#         away = ((((a.iloc[0]['AdjOE'] + h.iloc[0]['AdjDE']) / 2) * a_pos) / 100) - ((a.iloc[0]['Rk'] - h.iloc[0]['Rk']) / 25)
#         home += ((((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100) + (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#         away += ((((a.iloc[0]['3P%'] + h.iloc[0]['3P%D']) / 2) / 100) + (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#     away_score.append(round(away, 2))
#     home_score.append(round(home, 2))
    
# line['Predicted_Away_Score'] = away_score
# line['Predicted_Home_Score'] = home_score
# line['Predicted_Spread'] = -(line['Predicted_Home_Score'] - line['Predicted_Away_Score'])

# bet = []
# bet_by = []
# for index, row in line.iterrows():
#     bet_by.append(abs(float(row['Home_Spread']) - float(row['Predicted_Spread'])))
#     if row['Predicted_Spread'] < 0:
#         if float(row['Home_Spread']) < 0:
#             # Double Neg
#             if row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home')
#             elif row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             else:
#                 bet.append('Push')   
#         else:
#             # Mine Neg FD Pos
#             bet.append('Home')
#     elif row['Predicted_Spread'] > 0:
#         if float(row['Home_Spread']) > 0:
#             # Double Pos
#             if row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             elif row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home') 
#             else:
#                 bet.append('Push')
#         else:
#             # Mine Pos FD Neg
#             bet.append('Away')
#     else:
#         if float(row['Home_Spread']) < 0:
#            bet.append('Away')
#         elif float(row['Home_Spread']) > 0:
#            bet.append('Home')
#         else: 
#            bet.append('Push')
           


# line['bet'] = bet
# line['bet_by'] = bet_by
# line[['Away_Actual', 'Home_Actual', 'Actual_Spread', 'User_Diff', 'FD_Diff']] = np.nan
# line['date'] = date.today()

# e7['date'] = e7.apply(lambda x: (x['date'] + timedelta(days = 1)) if x['Away_Actual']!=x['Away_Actual'] else x['date'], axis = 1)
# e7['date'] = e7.apply(lambda x: date.today() if ((x['Away_Actual']!=x['Away_Actual'])  & (x['date'] > date.today())) else x['date'], axis = 1)
# e7 = pd.concat([e7, line])
# e7.drop_duplicates(subset=['date', 'Away', 'Home'], keep = 'last', inplace=True)


# ##################### EQUATION 8 #####################
# away_score = []
# home_score = []

# for index, row in line.iterrows():
#     a = stats[stats['line'] == row['Away']]
#     h = stats[stats['line'] == row['Home']]
#     if abs(float(row['Home_Spread'])) <= 5:
#         home =  (((((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) * (((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100)) * (SHOT_POS * 3)) + ((((h.iloc[0]['FTR'] + a.iloc[0]['FTRD']) / (2)) / 100) * (h.iloc[0]['FT%_x']) * (SHOT_POS * 1)) + ((1 - (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) + (((h.iloc[0]['FTR'] + a.iloc[0]['FTRD']) / (2*2)) / 100)) * (((h.iloc[0]['2P%'] + a.iloc[0]['2P%D']) / 2) / 100) * (SHOT_POS * 2)) + h.iloc[0]['HC_ADV'] + h.iloc[0]['SOS']
#         away = (((((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) * (((a.iloc[0]['3P%'] + h.iloc[0]['3P%D']) / 2) / 100)) * (SHOT_POS * 3)) + ((((a.iloc[0]['FTR'] + h.iloc[0]['FTRD']) / (2)) / 100) * (a.iloc[0]['FT%_x']) * (SHOT_POS * 1)) + ((1 - (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) + (((a.iloc[0]['FTR'] + h.iloc[0]['FTRD']) / (2*2)) / 100)) * (((a.iloc[0]['2P%'] + h.iloc[0]['2P%D']) / 2) / 100) * (SHOT_POS * 2)) + a.iloc[0]['SOS']
#     else:
#         h_pos = POS * (1 - ((((h.iloc[0]['TOR'] + a.iloc[0]['TORD']) / 2) - ((a.iloc[0]['TOR'] + h.iloc[0]['TORD']) / 2)) / 100)) * (1 - ((((a.iloc[0]['ORB'] + h.iloc[0]['DRB']) / 2) - ((h.iloc[0]['ORB'] + a.iloc[0]['DRB']) / 2)) / 100)) + ((((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100) + (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#         a_pos = POS * (1 - ((((a.iloc[0]['TOR'] + h.iloc[0]['TORD']) / 2) - ((h.iloc[0]['TOR'] + a.iloc[0]['TORD']) / 2)) / 100)) * (1 - ((((h.iloc[0]['ORB'] + a.iloc[0]['DRB']) / 2) - ((a.iloc[0]['ORB'] + h.iloc[0]['DRB']) / 2)) / 100)) + ((((a.iloc[0]['3P%'] + h.iloc[0]['3P%D']) / 2) / 100) + (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#         home = ((((h.iloc[0]['AdjOE'] + a.iloc[0]['AdjDE']) / 2) * h_pos) / 100) - ((h.iloc[0]['Rk'] - a.iloc[0]['Rk']) / 25)
#         away = ((((a.iloc[0]['AdjOE'] + h.iloc[0]['AdjDE']) / 2) * a_pos) / 100) - ((a.iloc[0]['Rk'] - h.iloc[0]['Rk']) / 25)
#         home += ((((h.iloc[0]['3P%'] + a.iloc[0]['3P%D']) / 2) / 100) + (((h.iloc[0]['3PR'] + a.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#         away += ((((a.iloc[0]['3P%'] + h.iloc[0]['3P%D']) / 2) / 100) + (((a.iloc[0]['3PR'] + h.iloc[0]['3PRD']) / 2) / 100) * 1.5)
#     away_score.append(round(away, 2))
#     home_score.append(round(home, 2))
    
# line['Predicted_Away_Score'] = away_score
# line['Predicted_Home_Score'] = home_score
# line['Predicted_Spread'] = -(line['Predicted_Home_Score'] - line['Predicted_Away_Score'])

# bet = []
# bet_by = []
# for index, row in line.iterrows():
#     bet_by.append(abs(float(row['Home_Spread']) - float(row['Predicted_Spread'])))
#     if row['Predicted_Spread'] < 0:
#         if float(row['Home_Spread']) < 0:
#             # Double Neg
#             if row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home')
#             elif row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             else:
#                 bet.append('Push')   
#         else:
#             # Mine Neg FD Pos
#             bet.append('Home')
#     elif row['Predicted_Spread'] > 0:
#         if float(row['Home_Spread']) > 0:
#             # Double Pos
#             if row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             elif row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home') 
#             else:
#                 bet.append('Push')
#         else:
#             # Mine Pos FD Neg
#             bet.append('Away')
#     else:
#         if float(row['Home_Spread']) < 0:
#            bet.append('Away')
#         elif float(row['Home_Spread']) > 0:
#            bet.append('Home')
#         else: 
#            bet.append('Push')
           


# line['bet'] = bet
# line['bet_by'] = bet_by
# line[['Away_Actual', 'Home_Actual', 'Actual_Spread', 'User_Diff', 'FD_Diff']] = np.nan
# line['date'] = date.today()

# e8['date'] = e8.apply(lambda x: (x['date'] + timedelta(days = 1)) if x['Away_Actual']!=x['Away_Actual'] else x['date'], axis = 1)
# e8['date'] = e8.apply(lambda x: date.today() if ((x['Away_Actual']!=x['Away_Actual'])  & (x['date'] > date.today())) else x['date'], axis = 1)
# e8 = pd.concat([e8, line])
# e8.drop_duplicates(subset=['date', 'Away', 'Home'], keep = 'last', inplace=True)


# ##################### EQUATION 9 #####################
# away_score = []
# home_score = []

# for index, row in line.iterrows():
#     a = stats[stats['line'] == row['Away']]
#     h = stats[stats['line'] == row['Home']]
#     home = ((((h.iloc[0]['AdjOE'] + a.iloc[0]['AdjDE']) / 2) * SHOT_POS) / 100) + h.iloc[0]['HC_ADV']
#     away = ((((a.iloc[0]['AdjOE'] + h.iloc[0]['AdjDE']) / 2) * SHOT_POS) / 100)
#     away_score.append(round(away, 2))
#     home_score.append(round(home, 2))
    
# line['Predicted_Away_Score'] = away_score
# line['Predicted_Home_Score'] = home_score
# line['Predicted_Spread'] = -(line['Predicted_Home_Score'] - line['Predicted_Away_Score'])

# bet = []
# bet_by = []
# for index, row in line.iterrows():
#     bet_by.append(abs(float(row['Home_Spread']) - float(row['Predicted_Spread'])))
#     if row['Predicted_Spread'] < 0:
#         if float(row['Home_Spread']) < 0:
#             # Double Neg
#             if row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home')
#             elif row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             else:
#                 bet.append('Push')   
#         else:
#             # Mine Neg FD Pos
#             bet.append('Home')
#     elif row['Predicted_Spread'] > 0:
#         if float(row['Home_Spread']) > 0:
#             # Double Pos
#             if row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             elif row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home') 
#             else:
#                 bet.append('Push')
#         else:
#             # Mine Pos FD Neg
#             bet.append('Away')
#     else:
#         if float(row['Home_Spread']) < 0:
#            bet.append('Away')
#         elif float(row['Home_Spread']) > 0:
#            bet.append('Home')
#         else: 
#            bet.append('Push')
           


# line['bet'] = bet
# line['bet_by'] = bet_by
# line[['Away_Actual', 'Home_Actual', 'Actual_Spread', 'User_Diff', 'FD_Diff']] = np.nan
# line['date'] = date.today()

# e9['date'] = e9.apply(lambda x: (x['date'] + timedelta(days = 1)) if x['Away_Actual']!=x['Away_Actual'] else x['date'], axis = 1)
# e9['date'] = e9.apply(lambda x: date.today() if ((x['Away_Actual']!=x['Away_Actual'])  & (x['date'] > date.today())) else x['date'], axis = 1)
# e9 = pd.concat([e9, line])
# e9.drop_duplicates(subset=['date', 'Away', 'Home'], keep = 'last', inplace=True)


# ##################### EQUATION 10 #####################
# away_score = []
# home_score = []

# for index, row in line.iterrows():
#     a = stats[stats['line'] == row['Away']]
#     h = stats[stats['line'] == row['Home']]
#     home = ((((h.iloc[0]['AdjOE'] + a.iloc[0]['AdjDE']) / 2) * SHOT_POS) / 100) + h.iloc[0]['HC_ADV'] + h.iloc[0]['SOS']
#     away = ((((a.iloc[0]['AdjOE'] + h.iloc[0]['AdjDE']) / 2) * SHOT_POS) / 100) + a.iloc[0]['SOS']
#     away_score.append(round(away, 2))
#     home_score.append(round(home, 2))
    
# line['Predicted_Away_Score'] = away_score
# line['Predicted_Home_Score'] = home_score
# line['Predicted_Spread'] = -(line['Predicted_Home_Score'] - line['Predicted_Away_Score'])

# bet = []
# bet_by = []
# for index, row in line.iterrows():
#     bet_by.append(abs(float(row['Home_Spread']) - float(row['Predicted_Spread'])))
#     if row['Predicted_Spread'] < 0:
#         if float(row['Home_Spread']) < 0:
#             # Double Neg
#             if row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home')
#             elif row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             else:
#                 bet.append('Push')   
#         else:
#             # Mine Neg FD Pos
#             bet.append('Home')
#     elif row['Predicted_Spread'] > 0:
#         if float(row['Home_Spread']) > 0:
#             # Double Pos
#             if row['Predicted_Spread'] > float(row['Home_Spread']):
#                 bet.append('Away')
#             elif row['Predicted_Spread'] < float(row['Home_Spread']):
#                 bet.append('Home') 
#             else:
#                 bet.append('Push')
#         else:
#             # Mine Pos FD Neg
#             bet.append('Away')
#     else:
#         if float(row['Home_Spread']) < 0:
#            bet.append('Away')
#         elif float(row['Home_Spread']) > 0:
#            bet.append('Home')
#         else: 
#            bet.append('Push')
           


# line['bet'] = bet
# line['bet_by'] = bet_by
# line[['Away_Actual', 'Home_Actual', 'Actual_Spread', 'User_Diff', 'FD_Diff']] = np.nan
# line['date'] = date.today()

# e10['date'] = e10.apply(lambda x: (x['date'] + timedelta(days = 1)) if x['Away_Actual']!=x['Away_Actual'] else x['date'], axis = 1)
# e10['date'] = e10.apply(lambda x: date.today() if ((x['Away_Actual']!=x['Away_Actual'])  & (x['date'] > date.today())) else x['date'], axis = 1)
# e10 = pd.concat([e10, line])
# e10.drop_duplicates(subset=['date', 'Away', 'Home'], keep = 'last', inplace=True)


# e1.to_pickle('Equation1.pkl')
# e2.to_pickle('Equation2.pkl')
# e3.to_pickle('Equation3.pkl')
# e4.to_pickle('Equation4.pkl')
# e5.to_pickle('Equation5.pkl')
# e6.to_pickle('Equation6.pkl')
# e7.to_pickle('Equation7.pkl')
# e8.to_pickle('Equation8.pkl')
# e9.to_pickle('Equation9.pkl')
# e10.to_pickle('Equation10.pkl')

# e1.to_pickle('SecondaryEquation1.pkl')
# e2.to_pickle('SecondaryEquation2.pkl')
# e3.to_pickle('SecondaryEquation3.pkl')
# e4.to_pickle('SecondaryEquation4.pkl')
# e5.to_pickle('SecondaryEquation5.pkl')
# e6.to_pickle('SecondaryEquation6.pkl')
# e7.to_pickle('SecondaryEquation7.pkl')
# e8.to_pickle('SecondaryEquation8.pkl')
# e9.to_pickle('SecondaryEquation9.pkl')
# e10.to_pickle('SecondaryEquation10.pkl')

# e8
